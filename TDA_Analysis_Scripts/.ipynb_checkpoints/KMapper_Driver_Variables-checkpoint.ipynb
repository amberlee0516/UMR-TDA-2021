# %%
import kmapper as km
from kmapper.plotlyviz import *

# %%
import sklearn
#from sklearn import ensemble
# DBSCAN from sklearn for clustering algorithms
from sklearn.cluster import DBSCAN
# PCA from sklearn for projection/lens creation
from sklearn.decomposition import PCA
# from sklearn.manifold import MDS
from itertools import combinations

# scipy for interpolation
# import scipy 
# from scipy.interpolate import *

# %%
# Plotly and Dash
import plotly.graph_objs as go
from kmapper.plotlyviz import plotlyviz
from kmapper.plotlyviz import *
from ipywidgets import (HBox, VBox)
import dash_html_components as html
import dash_core_components as dcc
import dash
from ipywidgets import interactive, HBox, VBox, widgets, interact
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
predicted_df = pd.read_csv(r"C:\Users\killiad\Documents\Senior\REU\Data\season_and_year.csv")

# %%
### Creating three main time spans and two overlapping time spans,
### a total of five time spans

# defining different time periods
# first decade
time_dec1 = [1993, 1994, 1995, 1997, 1998, 1999, 2000]
# second decade
time_dec2 = [2001, 2002,2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
# third decade
time_dec3 = [2014, 2015, 2016, 2017, 2018, 2019, 2020]
# overlap time periods for continuity
time_overlap1 = [1998, 1999, 2000, 2001, 2002,2003, 2004]
time_overlap2 = [2010, 2011, 2012, 2013, 2014, 2015, 2016]
time_list = [time_dec2]
time_list_names = ['01-13']

#Season_names = ["SPRING", "SUMMER", "FALL", "WINTER"]
Season_names = ["SUMMER"]
stratum_list = [1, 2, 3, 4, 5, 6, 7, 9]

nonempty_stratum = []
for i in stratum_list:
    if predicted_df[predicted_df['STRATUM'] == i].shape[0]!=0:
        nonempty_stratum.append(i)
print(nonempty_stratum) 


df_stratum_season_time_dict_list = []
df_stratum_season_time_dict = {}
s=""
for i in range(len(time_list)):
    for j in nonempty_stratum:
        for k in Season_names:
            s=str("Stratum ") + str(j)+ " " + k + " " + time_list_names[i] + str(": ")
            df_stratum_season_time_dict[s] = predicted_df[(predicted_df['YEAR'].isin(time_list[i])) &
                                                             (predicted_df['STRATUM'].isin([j])) & 
                                                             (predicted_df['SEASON'].isin([k]))]
            df_stratum_season_time_dict_list.append(df_stratum_season_time_dict)
            df_stratum_season_time_dict = {}
            s=""
print(len(df_stratum_season_time_dict_list))
# Out:
# [1, 2, 3]
# 3

# %%
def cluster_fun(dict_df, DBSCAN_EPSILON = 20, DBSCAN_MIN_SAMPLES = 1, N_CUBES = [7,7], PERC_OVERLAP = [.5,.5]):
    """

    """
    
    
    keys = list(dict_df.keys())
    print(keys)
    X = dict_df.get(keys[0])
    X = X[["PredictedWDP", "PredictedSECCHI", "PredictedTEMP", "PredictedDO", 
           "PredictedTURB", "PredictedVEL", "PredictedTP", 
           "PredictedTN", "PredictedSS", "PredictedCHLcal"]]
    if X.shape[0]<DBSCAN_MIN_SAMPLES:
        #print(X)
        print("Not enough data to cluster in ", keys, "_size = ", X.shape[0])
        print("DBSCAN_MIN_SAMPLES", DBSCAN_MIN_SAMPLES)
        return([DBSCAN_MIN_SAMPLES, X.shape[0]])
    
    
    db = DBSCAN(eps=20, min_samples=2).fit(X)
    # Number of clusters in labels, ignoring noise if present.
    labels = db.labels_
    n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
    n_noise_ = list(labels).count(-1)

    print('Estimated number of clusters: %d' % n_clusters_)
    print('Estimated number of noise points: %d' % n_noise_)
    
    return(db)

    
    
def mapper_pca_func(X, driver, key, DBSCAN_EPSILON = 20, DBSCAN_MIN_SAMPLES = 1, N_CUBES = [7,7], PERC_OVERLAP = [.5,.5]):
    """
    str(df_stratum_season_time_dict_list[1].keys())
    """
    
    continuous_variables = list(driver)
    var_to_index = {continuous_variables[i] : i for i in range(len(continuous_variables))}
    
    projected_vars = continuous_variables
    projected_var_indices = [var_to_index[var] for var in projected_vars]
    
    if X.shape[0]<10:
        print("Not enough data in ", keys, "_size = ", X.shape[0])
        return(X.shape[0])
    
    X.reset_index(drop = True, inplace = True)

    # defining clustering and kmapper parameters
    DBSCAN_EPSILON = DBSCAN_EPSILON
    DBSCAN_MIN_SAMPLES = DBSCAN_MIN_SAMPLES
    N_CUBES = N_CUBES
    PERC_OVERLAP = PERC_OVERLAP
    
    # create instance of clustering alg
    cluster_alg = sklearn.cluster.DBSCAN(eps=DBSCAN_EPSILON, min_samples=DBSCAN_MIN_SAMPLES, metric='euclidean')

    # Instantiate kepler mapper object
    mapper = km.KeplerMapper(verbose=0)
    
    # defining filter function as projection on to the first 2 component axis
    pca = PCA(n_components=1)
    lens = pca.fit_transform(X)
    principle_component = max(abs(pca.components_[0].min()), abs(pca.components_[0].max()))
    max_index = 0
    for i in range(len(pca.components_[0])):
        if abs(pca.components_[0][i]) == principle_component:
            max_index = i
    print("Primary variable: ", continuous_variables[max_index])
    print("Corresponding component: ", pca.components_[0][max_index])
    print('Explained Variance: ', pca.explained_variance_ratio_)

    # Generate the simplicial complex
    scomplex = mapper.map(lens, X, cover=km.Cover(n_cubes=N_CUBES, perc_overlap=PERC_OVERLAP), clusterer=cluster_alg,
                         remove_duplicate_nodes=True)  
    summary_variable = mapper.project(np.array(X), projection=projected_var_indices, scaler=None)

    pl_brewer = [[0.0, '#006837'],
             [0.1, '#1a9850'],
             [0.2, '#66bd63'],
             [0.3, '#a6d96a'],
             [0.4, '#d9ef8b'],
             [0.5, '#ffffbf'],
             [0.6, '#fee08b'],
             [0.7, '#fdae61'],
             [0.8, '#f46d43'],
             [0.9, '#d73027'],
             [1.0, '#a50026']]

    #color_values = lens[:,0] - lens[:,0].min()
    color_values = X[list(driver)[0]]
    #color_function_name = [continuous_variables[max_index]]
    color_function_name = [list(driver)[0]]
    my_colorscale = pl_brewer
    kmgraph,  mapper_summary, colorf_distribution = get_mapper_graph(scomplex, 
                                                                     color_values=color_values,  
                                                                     color_function_name=color_function_name, 
                                                                     colorscale=my_colorscale)

    bgcolor = 'rgba(10,10,10, 0.9)'
    # y_gridcolor = 'rgb(150,150,150)'# on a black background the gridlines are set on  grey

    plotly_graph_data = plotly_graph(kmgraph, graph_layout='fr', colorscale=my_colorscale, 
                                     factor_size=2.5, edge_linewidth=0.5)
    plot_title = str(keys[0]) + str(DBSCAN_EPSILON) + str(DBSCAN_EPSILON) + ', MIN_SAMPLES ' + str(DBSCAN_MIN_SAMPLES) 
    # plot_title = 'Pool 13, Summer 1993-1999; Epsilon ' + str(DBSCAN_EPSILON) + ', MIN_SAMPLES ' + str(DBSCAN_MIN_SAMPLES) 
    layout = plot_layout(title=plot_title,  
                         width=620, height=570,
                         annotation_text=get_kmgraph_meta(mapper_summary),  
                         bgcolor=bgcolor)

    # FigureWidget is responsible for event listeners

    fw_graph = go.FigureWidget(data=plotly_graph_data, layout=layout)
    fw_hist = node_hist_fig(colorf_distribution, bgcolor=bgcolor)
    fw_summary = summary_fig(mapper_summary, height=300)

    dashboard = hovering_widgets(kmgraph, 
                                 fw_graph, 
                                 bgcolor=bgcolor, 
                                 member_textbox_width=600)

    # DESIRED FILE PATH, CHANGE TO FIT YOUR LOCAL MACHINE
    directory_path = "Users\\killiad\\Documents\\Senior\\REU\\Mapper\\Driver_2\\"
    
    #Update the fw_graph colorbar, setting its title:
    fw_graph.data[1].marker.colorbar.title = 'dist to<br>x-min'
    #html_output_path = directory_path + str(keys[0]) + 'PCA_2' + 'all_var_' + 'Eps_' + str(DBSCAN_EPSILON) +'MinS_' + str(DBSCAN_MIN_SAMPLES) + 'NCUBES_' + str(N_CUBES[0]) + 'PEROvLp_' + str(PERC_OVERLAP[0]) + '.html'
    html_output_path = directory_path + str(key) + "_" + str(driver) + '_PCA_1' + 'all_var_' + 'Eps_' + str(DBSCAN_EPSILON) +'MinS_' + str(DBSCAN_MIN_SAMPLES) + 'NCUBES_' + str(N_CUBES) + 'PEROvLp_' + str(PERC_OVERLAP) + '.html'
    html_output_path = html_output_path.replace(" ", "-")
    html_output_path = html_output_path.replace(":", "_")
    html_output_path = "C:\\" + html_output_path
    mapper.visualize(scomplex, color_values=color_values, color_function_name=color_function_name, path_html=html_output_path,
                    lens = summary_variable, lens_names = projected_vars)
    return scomplex, X

# %%
dbclus_dict = {}
for i in df_stratum_season_time_dict_list:
    dbclus_dict[str(list(i.keys()))]=cluster_fun(i)
# Out:
# ['Stratum 1 SUMMER 01-13: ']
# Estimated number of clusters: 2
# Estimated number of noise points: 8
# ['Stratum 2 SUMMER 01-13: ']
# Estimated number of clusters: 4
# Estimated number of noise points: 10
# ['Stratum 3 SUMMER 01-13: ']
# Estimated number of clusters: 20
# Estimated number of noise points: 97

# %%
mapper_pca_output_dict = {}
#for i in df_stratum_season_time_dict_list:
#    mapper_pca_output_dict[str(list(i.keys()))] = mapper_pca_func(i)

# %%
n_cubes = [10]
perc_overlap = [.35]
mapper_pca_output_dict = {}
mapper_pca_output_df = {}
important_vars = ['PredictedTP', 'PredictedTN', 'PredictedCHLcal', 'PredictedSS', 'PredictedVEL', 'PredictedTEMP']
for cubes in n_cubes:
    for perc in perc_overlap:
        for i in df_stratum_season_time_dict_list:
            for drivers in combinations(important_vars, 2):
                keys = list(i.keys())
                print(keys, " ", str(drivers))
                df_var = i.get(keys[0])
                df_var = df_var[list(drivers)]
                scomplex, X = mapper_pca_func(df_var, drivers, keys[0], N_CUBES = cubes, PERC_OVERLAP = perc)
                mapper_pca_output_dict[str(list(i.keys())) + '_' + str(drivers)] = scomplex
                mapper_pca_output_df[str(list(i.keys())) + '_' + str(drivers)] = X
# Out:
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedTP', 'PredictedTN')
# Primary variable:  PredictedTN
# Corresponding component:  0.9991998369371135
# Explained Variance:  [0.89707147]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedTP', 'PredictedCHLcal')
# Primary variable:  PredictedCHLcal
# Corresponding component:  0.9999968508488449
# Explained Variance:  [0.99976003]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedTP', 'PredictedSS')
# Primary variable:  PredictedSS
# Corresponding component:  0.9999999734282392
# Explained Variance:  [0.99994884]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedTP', 'PredictedVEL')
# Primary variable:  PredictedTP
# Corresponding component:  0.9944970711650493
# Explained Variance:  [0.78497158]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedTP', 'PredictedTEMP')
# Primary variable:  PredictedTEMP
# Corresponding component:  -0.9996878918230891
# Explained Variance:  [0.98914543]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedTN', 'PredictedCHLcal')
# Primary variable:  PredictedCHLcal
# Corresponding component:  0.999987952715647
# Explained Variance:  [0.99791077]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedTN', 'PredictedSS')
# Primary variable:  PredictedSS
# Corresponding component:  0.999997449604286
# Explained Variance:  [0.999565]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedTN', 'PredictedVEL')
# Primary variable:  PredictedTN
# Corresponding component:  -0.9998620411420268
# Explained Variance:  [0.96826212]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedTN', 'PredictedTEMP')
# Primary variable:  PredictedTEMP
# Corresponding component:  -0.99950115413955
# Explained Variance:  [0.91014939]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedCHLcal', 'PredictedSS')
# Primary variable:  PredictedSS
# Corresponding component:  0.9986393272629995
# Explained Variance:  [0.82967041]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedCHLcal', 'PredictedVEL')
# Primary variable:  PredictedCHLcal
# Corresponding component:  0.9999986794350384
# Explained Variance:  [0.99993265]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedCHLcal', 'PredictedTEMP')
# Primary variable:  PredictedCHLcal
# Corresponding component:  0.9993891383699512
# Explained Variance:  [0.98037635]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedSS', 'PredictedVEL')
# Primary variable:  PredictedSS
# Corresponding component:  0.9999999620948207
# Explained Variance:  [0.99998552]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedSS', 'PredictedTEMP')
# Primary variable:  PredictedSS
# Corresponding component:  0.9999559990762587
# Explained Variance:  [0.99569094]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedVEL', 'PredictedTEMP')
# Primary variable:  PredictedTEMP
# Corresponding component:  -0.9999785956711703
# Explained Variance:  [0.99675758]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedTP', 'PredictedTN')
# Primary variable:  PredictedTN
# Corresponding component:  -0.9997922259208946
# Explained Variance:  [0.95131944]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedTP', 'PredictedCHLcal')
# Primary variable:  PredictedCHLcal
# Corresponding component:  0.9999993687009271
# Explained Variance:  [0.9999236]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedTP', 'PredictedSS')
# Primary variable:  PredictedSS
# Corresponding component:  0.9999999686915069
# Explained Variance:  [0.99998453]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedTP', 'PredictedVEL')
# Primary variable:  PredictedTP
# Corresponding component:  0.7480624651239548
# Explained Variance:  [0.68470298]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedTP', 'PredictedTEMP')
# Primary variable:  PredictedTEMP
# Corresponding component:  -0.9999641914131652
# Explained Variance:  [0.99553768]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedTN', 'PredictedCHLcal')
# Primary variable:  PredictedCHLcal
# Corresponding component:  0.999992876359228
# Explained Variance:  [0.99851095]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedTN', 'PredictedSS')
# Primary variable:  PredictedSS
# Corresponding component:  0.9999994836903758
# Explained Variance:  [0.99969995]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedTN', 'PredictedVEL')
# Primary variable:  PredictedTN
# Corresponding component:  -0.999910577085498
# Explained Variance:  [0.95505829]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedTN', 'PredictedTEMP')
# Primary variable:  PredictedTEMP
# Corresponding component:  -0.9998186323873592
# Explained Variance:  [0.91918663]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedCHLcal', 'PredictedSS')
# Primary variable:  PredictedSS
# Corresponding component:  0.9985648231130855
# Explained Variance:  [0.83522298]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedCHLcal', 'PredictedVEL')
# Primary variable:  PredictedCHLcal
# Corresponding component:  0.9999979027119293
# Explained Variance:  [0.99993309]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedCHLcal', 'PredictedTEMP')
# Primary variable:  PredictedCHLcal
# Corresponding component:  0.999999887527991
# Explained Variance:  [0.98323198]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedSS', 'PredictedVEL')
# Primary variable:  PredictedSS
# Corresponding component:  0.999999990597986
# Explained Variance:  [0.99998579]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedSS', 'PredictedTEMP')
# Primary variable:  PredictedSS
# Corresponding component:  0.9999995254145032
# Explained Variance:  [0.99660088]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedVEL', 'PredictedTEMP')
# Primary variable:  PredictedTEMP
# Corresponding component:  -0.9999775092487146
# Explained Variance:  [0.9958921]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedTP', 'PredictedTN')
# Primary variable:  PredictedTN
# Corresponding component:  0.9586272026715509
# Explained Variance:  [0.84676826]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedTP', 'PredictedCHLcal')
# Primary variable:  PredictedCHLcal
# Corresponding component:  0.9999967533127214
# Explained Variance:  [0.99995175]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedTP', 'PredictedSS')
# Primary variable:  PredictedSS
# Corresponding component:  0.9999993595165141
# Explained Variance:  [0.99997887]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedTP', 'PredictedVEL')
# Primary variable:  PredictedTP
# Corresponding component:  0.999998064915337
# Explained Variance:  [0.98512215]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedTP', 'PredictedTEMP')
# Primary variable:  PredictedTEMP
# Corresponding component:  -0.9997458807552068
# Explained Variance:  [0.97838577]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedTN', 'PredictedCHLcal')
# Primary variable:  PredictedCHLcal
# Corresponding component:  0.9999912194622765
# Explained Variance:  [0.99981096]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedTN', 'PredictedSS')
# Primary variable:  PredictedSS
# Corresponding component:  0.9999984276223557
# Explained Variance:  [0.99991853]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedTN', 'PredictedVEL')
# Primary variable:  PredictedTN
# Corresponding component:  0.9999797959201245
# Explained Variance:  [0.99605416]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedTN', 'PredictedTEMP')
# Primary variable:  PredictedTEMP
# Corresponding component:  -0.9999947587909684
# Explained Variance:  [0.92140395]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedCHLcal', 'PredictedSS')
# Primary variable:  PredictedSS
# Corresponding component:  0.9488572997616324
# Explained Variance:  [0.76162737]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedCHLcal', 'PredictedVEL')
# Primary variable:  PredictedCHLcal
# Corresponding component:  0.9999999978382932
# Explained Variance:  [0.99999918]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedCHLcal', 'PredictedTEMP')
# Primary variable:  PredictedCHLcal
# Corresponding component:  0.9999986343245949
# Explained Variance:  [0.9975864]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedSS', 'PredictedVEL')
# Primary variable:  PredictedSS
# Corresponding component:  0.9999999996261097
# Explained Variance:  [0.99999966]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedSS', 'PredictedTEMP')
# Primary variable:  PredictedSS
# Corresponding component:  0.9999941673373234
# Explained Variance:  [0.99902076]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedVEL', 'PredictedTEMP')
# Primary variable:  PredictedTEMP
# Corresponding component:  -0.9999995811733763
# Explained Variance:  [0.99965955]

# %%
n_cubes = [10]
perc_overlap = [.35]
mapper_pca_output_dict = {}
mapper_pca_output_df = {}
important_vars = ['PredictedTP', 'PredictedTN', 'PredictedCHLcal', 'PredictedSS', 'PredictedVEL', 'PredictedTEMP']
for cubes in n_cubes:
    for perc in perc_overlap:
        for i in df_stratum_season_time_dict_list:
            for drivers in combinations(important_vars, 3):
                keys = list(i.keys())
                print(keys, " ", str(drivers))
                df_var = i.get(keys[0])
                df_var = df_var[list(drivers)]
                scomplex, X = mapper_pca_func(df_var, drivers, keys[0], N_CUBES = cubes, PERC_OVERLAP = perc)
                mapper_pca_output_dict[str(list(i.keys())) + '_' + str(drivers)] = scomplex
                mapper_pca_output_df[str(list(i.keys())) + '_' + str(drivers)] = X
# Out:
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedTP', 'PredictedTN', 'PredictedCHLcal')
# Primary variable:  PredictedCHLcal
# Corresponding component:  0.9999848021310634
# Explained Variance:  [0.99767181]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedTP', 'PredictedTN', 'PredictedSS')
# Primary variable:  PredictedSS
# Corresponding component:  0.9999974230495156
# Explained Variance:  [0.99951389]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedTP', 'PredictedTN', 'PredictedVEL')
# Primary variable:  PredictedTN
# Corresponding component:  0.9990755107874961
# Explained Variance:  [0.87149477]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedTP', 'PredictedTN', 'PredictedTEMP')
# Primary variable:  PredictedTEMP
# Corresponding component:  -0.9991966029792424
# Explained Variance:  [0.9012004]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedTP', 'PredictedCHLcal', 'PredictedSS')
# Primary variable:  PredictedSS
# Corresponding component:  0.9986393138425803
# Explained Variance:  [0.82963526]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedTP', 'PredictedCHLcal', 'PredictedVEL')
# Primary variable:  PredictedCHLcal
# Corresponding component:  0.9999955301763822
# Explained Variance:  [0.99969271]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedTP', 'PredictedCHLcal', 'PredictedTEMP')
# Primary variable:  PredictedCHLcal
# Corresponding component:  0.9993859171830831
# Explained Variance:  [0.98014618]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedTP', 'PredictedSS', 'PredictedVEL')
# Primary variable:  PredictedSS
# Corresponding component:  0.9999999355225749
# Explained Variance:  [0.99993437]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedTP', 'PredictedSS', 'PredictedTEMP')
# Primary variable:  PredictedSS
# Corresponding component:  0.9999559720428541
# Explained Variance:  [0.99564022]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedTP', 'PredictedVEL', 'PredictedTEMP')
# Primary variable:  PredictedTEMP
# Corresponding component:  -0.999666269571551
# Explained Variance:  [0.98597554]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedTN', 'PredictedCHLcal', 'PredictedSS')
# Primary variable:  PredictedSS
# Corresponding component:  0.9986365420246279
# Explained Variance:  [0.8293725]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedTN', 'PredictedCHLcal', 'PredictedVEL')
# Primary variable:  PredictedCHLcal
# Corresponding component:  0.9999866328690498
# Explained Variance:  [0.9978437]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedTN', 'PredictedCHLcal', 'PredictedTEMP')
# Primary variable:  PredictedCHLcal
# Corresponding component:  0.9993773800891318
# Explained Variance:  [0.97837083]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedTN', 'PredictedSS', 'PredictedVEL')
# Primary variable:  PredictedSS
# Corresponding component:  0.9999974116913692
# Explained Variance:  [0.99955054]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedTN', 'PredictedSS', 'PredictedTEMP')
# Primary variable:  PredictedSS
# Corresponding component:  0.9999534445734778
# Explained Variance:  [0.99525974]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedTN', 'PredictedVEL', 'PredictedTEMP')
# Primary variable:  PredictedTEMP
# Corresponding component:  -0.9994791661236715
# Explained Variance:  [0.90746908]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedCHLcal', 'PredictedSS', 'PredictedVEL')
# Primary variable:  PredictedSS
# Corresponding component:  0.9986393002526465
# Explained Variance:  [0.82966046]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedCHLcal', 'PredictedSS', 'PredictedTEMP')
# Primary variable:  PredictedSS
# Corresponding component:  0.9986035596457472
# Explained Variance:  [0.82671477]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedCHLcal', 'PredictedVEL', 'PredictedTEMP')
# Primary variable:  PredictedCHLcal
# Corresponding component:  0.9993878107955311
# Explained Variance:  [0.98031176]
# ['Stratum 1 SUMMER 01-13: ']   ('PredictedSS', 'PredictedVEL', 'PredictedTEMP')
# Primary variable:  PredictedSS
# Corresponding component:  0.999955961040272
# Explained Variance:  [0.99567659]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedTP', 'PredictedTN', 'PredictedCHLcal')
# Primary variable:  PredictedCHLcal
# Corresponding component:  0.999992245356825
# Explained Variance:  [0.99843478]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedTP', 'PredictedTN', 'PredictedSS')
# Primary variable:  PredictedSS
# Corresponding component:  0.9999994523790972
# Explained Variance:  [0.99968448]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedTP', 'PredictedTN', 'PredictedVEL')
# Primary variable:  PredictedTN
# Corresponding component:  -0.999692307828093
# Explained Variance:  [0.91058927]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedTP', 'PredictedTN', 'PredictedTEMP')
# Primary variable:  PredictedTEMP
# Corresponding component:  -0.9997823159552074
# Explained Variance:  [0.91542199]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedTP', 'PredictedCHLcal', 'PredictedSS')
# Primary variable:  PredictedSS
# Corresponding component:  0.9985647987572607
# Explained Variance:  [0.83521221]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedTP', 'PredictedCHLcal', 'PredictedVEL')
# Primary variable:  PredictedCHLcal
# Corresponding component:  0.9999972713018314
# Explained Variance:  [0.9998567]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedTP', 'PredictedCHLcal', 'PredictedTEMP')
# Primary variable:  PredictedCHLcal
# Corresponding component:  0.99999925638413
# Explained Variance:  [0.98315814]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedTP', 'PredictedSS', 'PredictedVEL')
# Primary variable:  PredictedSS
# Corresponding component:  0.9999999592891218
# Explained Variance:  [0.99997032]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedTP', 'PredictedSS', 'PredictedTEMP')
# Primary variable:  PredictedSS
# Corresponding component:  0.9999994940921337
# Explained Variance:  [0.99658551]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedTP', 'PredictedVEL', 'PredictedTEMP')
# Primary variable:  PredictedTEMP
# Corresponding component:  -0.999941526754332
# Explained Variance:  [0.99146694]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedTN', 'PredictedCHLcal', 'PredictedSS')
# Primary variable:  PredictedSS
# Corresponding component:  0.9985642208929071
# Explained Variance:  [0.83501434]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedTN', 'PredictedCHLcal', 'PredictedVEL')
# Primary variable:  PredictedCHLcal
# Corresponding component:  0.9999907795323558
# Explained Variance:  [0.99844424]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedTN', 'PredictedCHLcal', 'PredictedTEMP')
# Primary variable:  PredictedCHLcal
# Corresponding component:  0.99999276282333
# Explained Variance:  [0.98179264]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedTN', 'PredictedSS', 'PredictedVEL')
# Primary variable:  PredictedSS
# Corresponding component:  0.999999474287345
# Explained Variance:  [0.99968575]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedTN', 'PredictedSS', 'PredictedTEMP')
# Primary variable:  PredictedSS
# Corresponding component:  0.9999990089899883
# Explained Variance:  [0.99630287]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedTN', 'PredictedVEL', 'PredictedTEMP')
# Primary variable:  PredictedTEMP
# Corresponding component:  -0.9997958843194886
# Explained Variance:  [0.91571938]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedCHLcal', 'PredictedSS', 'PredictedVEL')
# Primary variable:  PredictedSS
# Corresponding component:  0.9985648197218934
# Explained Variance:  [0.83521309]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedCHLcal', 'PredictedSS', 'PredictedTEMP')
# Primary variable:  PredictedSS
# Corresponding component:  0.9985643452191858
# Explained Variance:  [0.83285601]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedCHLcal', 'PredictedVEL', 'PredictedTEMP')
# Primary variable:  PredictedCHLcal
# Corresponding component:  0.9999977904656464
# Explained Variance:  [0.98316736]
# ['Stratum 2 SUMMER 01-13: ']   ('PredictedSS', 'PredictedVEL', 'PredictedTEMP')
# Primary variable:  PredictedSS
# Corresponding component:  0.9999995160064384
# Explained Variance:  [0.99658677]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedTP', 'PredictedTN', 'PredictedCHLcal')
# Primary variable:  PredictedCHLcal
# Corresponding component:  0.9999879720319637
# Explained Variance:  [0.99976274]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedTP', 'PredictedTN', 'PredictedSS')
# Primary variable:  PredictedSS
# Corresponding component:  0.9999977870686284
# Explained Variance:  [0.9998974]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedTP', 'PredictedTN', 'PredictedVEL')
# Primary variable:  PredictedTN
# Corresponding component:  0.9586134170679405
# Explained Variance:  [0.84412627]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedTP', 'PredictedTN', 'PredictedTEMP')
# Primary variable:  PredictedTEMP
# Corresponding component:  -0.9997371327713426
# Explained Variance:  [0.90306019]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedTP', 'PredictedCHLcal', 'PredictedSS')
# Primary variable:  PredictedSS
# Corresponding component:  0.9488561349430709
# Explained Variance:  [0.76161656]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedTP', 'PredictedCHLcal', 'PredictedVEL')
# Primary variable:  PredictedCHLcal
# Corresponding component:  0.9999967511511272
# Explained Variance:  [0.99995093]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedTP', 'PredictedCHLcal', 'PredictedTEMP')
# Primary variable:  PredictedCHLcal
# Corresponding component:  0.9999953881364416
# Explained Variance:  [0.9975384]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedTP', 'PredictedSS', 'PredictedVEL')
# Primary variable:  PredictedSS
# Corresponding component:  0.9999993591426237
# Explained Variance:  [0.99997853]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedTP', 'PredictedSS', 'PredictedTEMP')
# Primary variable:  PredictedSS
# Corresponding component:  0.9999935267257571
# Explained Variance:  [0.99899967]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedTP', 'PredictedVEL', 'PredictedTEMP')
# Primary variable:  PredictedTEMP
# Corresponding component:  -0.999745464921288
# Explained Variance:  [0.97806005]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedTN', 'PredictedCHLcal', 'PredictedSS')
# Primary variable:  PredictedSS
# Corresponding component:  0.9488543154968881
# Explained Variance:  [0.76158492]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedTN', 'PredictedCHLcal', 'PredictedVEL')
# Primary variable:  PredictedCHLcal
# Corresponding component:  0.9999912173014995
# Explained Variance:  [0.99981014]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedTN', 'PredictedCHLcal', 'PredictedTEMP')
# Primary variable:  PredictedCHLcal
# Corresponding component:  0.9999898540182517
# Explained Variance:  [0.99739831]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedTN', 'PredictedSS', 'PredictedVEL')
# Primary variable:  PredictedSS
# Corresponding component:  0.9999984272484199
# Explained Variance:  [0.9999182]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedTN', 'PredictedSS', 'PredictedTEMP')
# Primary variable:  PredictedSS
# Corresponding component:  0.9999925950249593
# Explained Variance:  [0.99893946]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedTN', 'PredictedVEL', 'PredictedTEMP')
# Primary variable:  PredictedTEMP
# Corresponding component:  -0.9999943433341577
# Explained Variance:  [0.92111496]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedCHLcal', 'PredictedSS', 'PredictedVEL')
# Primary variable:  PredictedSS
# Corresponding component:  0.9488572998741176
# Explained Variance:  [0.76162719]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedCHLcal', 'PredictedSS', 'PredictedTEMP')
# Primary variable:  PredictedSS
# Corresponding component:  0.9488556005868433
# Explained Variance:  [0.76109784]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedCHLcal', 'PredictedVEL', 'PredictedTEMP')
# Primary variable:  PredictedCHLcal
# Corresponding component:  0.9999986321634026
# Explained Variance:  [0.99758558]
# ['Stratum 3 SUMMER 01-13: ']   ('PredictedSS', 'PredictedVEL', 'PredictedTEMP')
# Primary variable:  PredictedSS
# Corresponding component:  0.9999941669636266
# Explained Variance:  [0.99902042]

# %%
import json


json = json.dumps(mapper_pca_output_dict)
f = open(r"C:\Users\killiad\Documents\Senior\REU\Mapper\PCA_1_NO_COND\TDA1PCA15Cubes35perc.json","w")
f.write(json)
f.close()

# %%
predicted_df.head()

# %%
mapper_pca_output_dict["['Stratum 1 WINTER 93-00: ']"]['nodes']['cube2_cluster0']

# %%
import pickle as pk
pickle = pk.dump(mapper_pca_output_df, open(r"C:\Users\killiad\Documents\Senior\REU\Mapper\PCA_1_NO_COND\TDA1PCA15Cubes35perc.p", "wb"))
