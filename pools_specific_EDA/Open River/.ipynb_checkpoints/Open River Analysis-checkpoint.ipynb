# %% [markdown]
# ### Imports and function declaration

# %%
import pandas as pd
import pickle
import os
import matplotlib.pyplot as plt
import numpy as np
from geopy import distance
import time
pd.set_option('display.max_columns', None)

# useful functions and classes

# This class stores the latitude and longitude of a sample, and indicates 
# if this location has the desired variable we are estimating
class Location:
    def __init__(self,latitude,longitude,hasv,ID,value):
        self.ID = ID
        self.latitude = latitude
        self.longitude = longitude
        self.hasv = hasv
        self.value = value
        
    def __str__(self):
        return str(self.ID)

# Calculates the distance between 2 samples in km
def getdist(S1,S2):
    # radius of earth in km
    coords_1 = (S1.latitude, S1.longitude)
    coords_2 = (S2.latitude, S2.longitude)
    dist = distance.distance(coords_1, coords_2).km
    return dist

# filters out data if a point is missing in one of the colunns
def filterblanks(columns,data,blank):
    # if blank is true, remove rows with blanks in these columns
    # if blank is false, remove rows with non blanks or non zeros in these columns
    for c in columns:
        if blank:
            data = data[data[c].notnull()].copy()
        else:
            data = data[data[c].isnull()].copy()
    return data

# PRE: all locations in the dataframe are
# unique
def DistanceMatrix(dataframe,variable):
    # the list of location objects
    locations = []
    # the list of indexes where the the row is located in the dataframe
    #indexes = []
    for index,row in dataframe.iterrows():
        # make a location object on this row
        if pd.isnull(row[variable]):
            hasv = False
        else:
            hasv = True
        locations.append(Location(row["LATITUDE"],row["LONGITUDE"],hasv,row["LOCATCD"],row[variable]))
        #indexes.append(index)
        
    matrix = pd.DataFrame(0,index=locations,columns=locations)
    for ci,column in enumerate(locations):
        for ri,row in enumerate(locations):
            if ri>ci:
                # compute distance between column and row
                dist = getdist(row,column)
            elif ci>ri:
                dist = matrix.iloc[ci,ri]
            # put this distance in the dataframe
            else:
                continue
            matrix.iloc[ri,ci] = dist
    return matrix

def changeVar(DM,data,variable):
    locations = DM.index
    # loop through each location
    for i,loc in enumerate(locations):
        ID = loc.ID
        row = data[data["LOCATCD"]==ID]
        if pd.isnull(row[variable]):
            locations[i].hasv = False
            locations[i].value = None
        else:
            locations[i].hasv = True
            locations[i].value = row[variable]
            
    DM.index = locations
    DM.columns = locations
        
def getclosest(numclosest,distancematrix,location,testing):
    # Make a set of the closest locations that contain variable
    closest = {}
    column = distancematrix.loc[:,location].copy()
    #print(type(distancematrix.index[0]))
    # Filter the locations that dont have the desired variable
    doesnthavev = []
    for i in range(len(column)):
        if not column.index[i].hasv:
            doesnthavev.append(column.index[i])
    column.drop(doesnthavev,inplace = True)
    #print(type(column))
    column.sort_values(inplace = True)
    # Are we predicting for a value we already have?
    if testing:
        return column.iloc[1:numclosest+1]
    else:
        return column.iloc[0:numclosest]

# Key: Location Code
# Value: List of tuples (locatcd,distance,value)
def makeDict(data,variable,numclosest,testing):
    D = DistanceMatrix(data,variable)
    # Loop through each location without a value for variable
    closestDict = {}
    for loc in D.columns:
        if not loc.hasv or testing:
            # Get the closest locations to loc THAT ISN'T LOC
            closest = getclosest(numclosest,D,loc,testing)
            # The list of tuples that contain location id, the distance, and the value for variable
            tuples = []
            for i,dist in enumerate(closest):
                ID = closest.index[i].ID
                val = closest.index[i].value
                tuples.append((ID,dist,val))
            closestDict[loc.ID] = tuples
    return closestDict

def predict(tuples,numclosest = 2):
    loc2 = tuples[0]
    loc3 = tuples[1]
    d12 = loc2[1]
    val2 = loc2[2]
    d13 = loc3[1]
    val3 = loc3[2]
    
    c2 = d12/(d12+d13)
    c3 = d13/(d12+d13)
    
    predicted = c2*val2+c3*val3
    
    return predicted

# NEEDS WORK
def addpredictions(df,variables,numclosest):
    # make prediction and insert for each variable
    first = True
    for var in variables:
        if first:
            DM = DistanceMatrix(df,var)
        else:
            changeVar(DM,df,var)
            
        for loc in DM.columns:
            if not loc.hasv:
                # Get the closest locations to loc
                closest = getclosest(numclosest,DM,loc)
                # The list of tuples that contain location id, the distance, and the value for variable
                tuples = []
                for i,dist in enumerate(closest):
                    ID = closest.index[i].ID
                    val = closest.index[i].value
                    tuples.append((ID,dist,val))
                closestDict[loc.ID] = tuples

        
'''
data - the pandas dataframe that is ready to interpolate missing values
MUST HAVE "LATITUDE", "LONGITUDE","YEAR", "TIME CODE", "LOCATCD" columns

missing_vars - the list of column names (as strings) of the dataframe that we should attempt to fill in

numlocations - the number of locations used to predict the new value, default is 2 (currently the only option implemented)

RETURN - a dataframe with extra columns saying the predicted values of the missing_vars
'''
def linear_interpolate(data,missing_vars,numlocations = 2,testing = False):
    print("Building a new dataframe with predicted values")
    start_time = time.time()
    # Testing for duplicated locations if needed
    #s = qualdata_noprediction["LOCATCD"].duplicated(keep=False)
    # get the years and timecodes for this dataset
    # predictions can only be made if the point is in the same year and time code (what if we don't need to do this)
    years = data["YEAR"].unique()
    seasons = data["SEASON"].unique()
    data_prediction = pd.DataFrame()
    for year in years:
        for season in seasons:
            print("Appending predicted data for ",year,"  ",season)
            # curset is the current set of rows we are predicting for
            curset = data[(data["YEAR"]==year) & (data["SEASON"]==season)].copy()
            print("Size of this year and season:", curset.shape)
            
            for var in missing_vars:
                print("Interpolating "+var)
                newcolumn = "Predicted"+var
                curset[newcolumn] = 0
                
                #check to see if there are enough valid locations
                # that can be used to predict
                if not testing:
                    bad = bool((curset[var].notnull().sum()<numlocations))
                else:
                    bad = bool((curset[var].notnull().sum()<numlocations+1))
                
                # Returns a dictionary mapping each location code to a tuple with prediction information
                Dict = makeDict(curset,var,numlocations,testing)

                if(bad):
                    print("Less than "+str(numlocations)+" locations have "+var+" in this set, dropping rows without "+var)
                    curset = curset[curset[var].notnull()]
                    curset[newcolumn] = curset[var]
                    print("Current set is now ",curset.shape)
                else:
                    #put in predicted variable
                    for index,row in curset.iterrows():
                        if pd.isnull(row[var]) or testing:
                            try:
                                curset.loc[index,newcolumn] = predict(Dict[row["LOCATCD"]])
                            except ZeroDivisionError:
                                print("Couldn't predict for ", str(row["LOCATCD"]))
                                print(Dict[row["LOCATCD"]])
                                curset.loc[index,newcolumn] = None
                        else:
                            curset.loc[index,newcolumn] = row[var]

            data_prediction = data_prediction.append(curset,ignore_index=True)  
            
    print("Final data set size is ",data_prediction.shape)
    print(f"Interpolating took {(time.time()-start_time)/60} minutes")
    return data_prediction

# %% [markdown]
# ### Loading and Filtering data

# %%
water_path = r"..\..\LTRM data\cleaned_data.csv"
water_data = pd.read_csv(water_path, low_memory = False)
veg_path = r"..\..\LTRM data\ltrm_vegsrs_data_lat_long.csv"
veg_data = pd.read_csv(veg_path, low_memory = False)

continuous = ['TN','TP','TEMP','DO','TURB','COND','VEL','SS','WDP','CHLcal','SECCHI']
seasons = {3:"SPRING",4:"SPRING",5:"SPRING",6:"SUMMER",7:"SUMMER",8:"SUMMER",9:"FALL",10:"FALL",11:"FALL",12:"WINTER",1:"WINTER",2:"WINTER"}

print("Now adding a year column")
water_data["YEAR"] = pd.DatetimeIndex(water_data["DATE"]).year
print("Now adding a month column")
water_data["MONTH"] = pd.DatetimeIndex(water_data["DATE"]).month
print("Now adding a season column")
water_data["SEASON"] = water_data["MONTH"]
water_data = water_data.replace({"SEASON":seasons})

print("Veg data")
print(veg_data.columns)
print(veg_data.shape)

print("\n\n Water data")
print(water_data.columns)
print(water_data.shape)

print("Filtering by pool")
veg_data = veg_data[veg_data["FLDNUM"]==5]
water_data = water_data[water_data["FLDNUM"]==5]
print(veg_data.shape)
print(water_data.shape)
# Out:
# Now adding a year column
# Now adding a month column
# Now adding a season column
# Veg data
# Index(['BARCODE', 'ROWNUM', 'PAGENUM', 'FLDNUM', 'PROJCD', 'POOL', 'DATE',
#        'LDRCODE', 'RCRDCODE', 'DETRITUS', 'SBSTRATE', 'SITECD', 'MSTRATUM',
#        'ASTRATUM', 'RIVMILE', 'VEG_S', 'VEG_RF', 'VEG_E', 'VEG_A', 'VEG_NRF',
#        'VEG_U', 'COV_NRF', 'COV_RF', 'COV_E', 'EAST1', 'NORTH1', 'ZONE',
#        'ACCUR1', 'METHOD', 'EAST2', 'NORTH2', 'ACCUR2', 'ZONE_U', 'EAST_U',
#        'NORTH_U', 'GRIDCODE', 'EAST_15', 'NORTH_15', 'HABITAT1', 'HABITAT2',
#        'HABITAT3', 'HABITAT4', 'HABITAT5', 'HABITAT6', 'DEPTH1', 'DEPTH2',
#        'DEPTH3', 'DEPTH4', 'DEPTH5', 'DEPTH6', 'DENSITY1', 'DENSITY2',
#        'DENSITY3', 'DENSITY4', 'DENSITY5', 'DENSITY6', 'BATCHNUM', 'SPPCD',
#        'VISUAL1', 'VISUAL2', 'VISUAL3', 'VISUAL4', 'VISUAL5', 'VISUAL6',
#        'RAKE1', 'RAKE2', 'RAKE3', 'RAKE4', 'RAKE5', 'RAKE6', 'ADDSPP',
#        'COVSPP', 'QECODE', 'VOUCHER', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')
# (125063, 76)
#
#
#  Water data
# Index(['SHEETBAR', 'TN', 'TP', 'TEMP', 'DO', 'TURB', 'COND', 'VEL', 'SS',
#        'WDP', 'CHLcal', 'SECCHI', 'LONGITUDE', 'LATITUDE', 'DATE', 'FLDNUM',
#        'LOCATCD', 'STRATUM', 'YEAR', 'MONTH', 'SEASON'],
#       dtype='object')
# (105143, 21)
# Filtering by pool
# (0, 76)
# (15760, 21)

# %% [markdown]
# Checking for weird location codes

# %%
num_weird = 0
for index,row in water_data.iterrows():
    if not str(row["LOCATCD"]).isnumeric():
        num_weird += 1
        #print(row["LOCATCD"],row["YEAR"])
print(num_weird)
# Out:
# 3284

# %% [markdown]
# Insanity check for time seasons

# %%
water_data["SEASON"].unique()
# Out:
# array(['SUMMER', 'FALL', 'WINTER', 'SPRING'], dtype=object)

# %% [markdown]
# #### Checking stratum data size

# %%
water_data["STRATUM"].unique()
# Out:
# array([nan,  1.,  2.])

# %%
water_data[water_data["STRATUM"].isna()]
# Out:
#        SHEETBAR     TN     TP  TEMP    DO   TURB   COND   VEL      SS   WDP  \
# 72964  45002343  3.989    NaN  27.7   6.1  153.0  565.0   NaN  247.70   3.5
# 72965  45002344  1.211    NaN  27.8   3.4   46.0  494.0  0.11   44.80   5.6
# 72966  45002345  4.022    NaN  27.6   5.9  174.0  564.0   NaN  209.50   5.0
# 72967  45002349  4.056    NaN  27.5   5.8   93.0  545.0  0.20  122.70   4.0
# 72968  45002350  4.028    NaN  27.6   6.0  151.0  563.0   NaN  201.30  12.5
# ...         ...    ...    ...   ...   ...    ...    ...   ...     ...   ...
# 88719  45025434  2.480  0.190  12.2  10.8   28.0  617.0   NaN   42.40   8.2
# 88720  45025435  1.953  0.187  12.2  10.8   32.0  621.0   NaN   45.28   1.8
# 88721  45025436  2.034  0.179  12.4  11.0   29.0  622.0   NaN   39.84   1.9
# 88722  45025437  1.370  0.179  14.8   6.9   54.0  863.0   NaN   50.55   1.6
# 88723  45025438  2.056  0.189  12.3  10.8   30.0  623.0   NaN   43.80   2.9
#
#          CHLcal  SECCHI  LONGITUDE   LATITUDE        DATE  FLDNUM  LOCATCD  \
# 72964       NaN    11.0 -89.512066  37.604644  07/09/1996       5  M078.0B
# 72965       NaN    37.0 -89.509512  37.578378  07/09/1996       5  BM00.7S
# 72966       NaN    11.0 -89.498738  37.498336  07/09/1996       5  M070.2A
# 72967       NaN    12.0 -89.451772  37.455464  07/09/1996       5  M066.4C
# 72968       NaN    13.0 -89.458085  37.455311  07/09/1996       5  M066.3B
# ...         ...     ...        ...        ...         ...     ...      ...
# 88719  31.55051    31.0 -89.458085  37.455311  11/12/2020       5  M066.3B
# 88720  28.01871    29.0 -89.456054  37.450457  11/12/2020       5  M066.3A
# 88721  29.46354    32.0 -89.498738  37.498336  11/12/2020       5  M070.2A
# 88722  15.01524    23.0 -89.509512  37.578378  11/12/2020       5  BM00.7S
# 88723  28.66086    28.0 -89.512066  37.604644  11/12/2020       5  M078.0B
#
#        STRATUM  YEAR  MONTH  SEASON
# 72964      NaN  1996      7  SUMMER
# 72965      NaN  1996      7  SUMMER
# 72966      NaN  1996      7  SUMMER
# 72967      NaN  1996      7  SUMMER
# 72968      NaN  1996      7  SUMMER
# ...        ...   ...    ...     ...
# 88719      NaN  2020     11    FALL
# 88720      NaN  2020     11    FALL
# 88721      NaN  2020     11    FALL
# 88722      NaN  2020     11    FALL
# 88723      NaN  2020     11    FALL
#
# [3284 rows x 21 columns]

# %%
sum(water_data["STRATUM"] == 1)
# Out:
# 6780

# %%
sum(water_data["STRATUM"]==2)
# Out:
# 5696

# %% [markdown]
# #### Taking a look at our variables

# %%
water_data[continuous].describe()
# Out:
#                 TN           TP          TEMP            DO          TURB  \
# count  8104.000000  7878.000000  15739.000000  15701.000000  15663.000000
# mean      2.790888     0.249802     17.068537      8.846844    106.956841
# std       1.210345     0.118131      9.319938      2.664854    115.454703
# min       0.123000     0.005000      0.100000      0.000000      4.000000
# 25%       1.922000     0.179000     12.700000      6.900000     38.000000
# 50%       2.803500     0.227000     17.200000      8.200000     74.000000
# 75%       3.558000     0.296000     26.100000     10.200000    126.000000
# max      22.576000     1.527000     34.700000     25.000000   1565.000000
#
#                COND          VEL            SS           WDP        CHLcal  \
# count  15754.000000  4709.000000  15741.000000  15708.000000  15236.000000
# mean     522.265076     0.752291    144.221352      6.912277     18.225826
# std       94.551286     0.455241    149.136698      3.962754     13.039564
# min       59.000000     0.000000     -1.000000      0.300000     -1.000000
# 25%      465.000000     0.390000     52.200000      3.900000      9.179300
# 50%      526.000000     0.750000     99.200000      6.400000     14.737150
# 75%      587.000000     1.080000    178.750000      9.300000     23.629920
# max     1237.000000     2.270000   2282.000000     31.900000    214.230450
#
#              SECCHI
# count  15685.000000
# mean      24.139560
# std       13.622412
# min        1.000000
# 25%       14.000000
# 50%       21.000000
# 75%       31.000000
# max      153.000000

# %% [markdown]
# #### Boxplots and histograms

# %%
var = "TP"
water_data[[var,'STRATUM']].boxplot(by='STRATUM', meanline=True, showmeans=True, showcaps=True, 
                showbox=True, showfliers=True,return_type = 'axes')
plt.suptitle('') # that's what you're after
plt.show()

# %%
water_data[[var,'STRATUM']].hist(by='STRATUM')
plt.suptitle(var) # that's what you're after
# Out:
# Text(0.5, 0.98, 'TP')

# %% [markdown]
# #### Missing data

# %%
water_data[continuous].isnull().sum()
# Out:
# TN         7656
# TP         7882
# TEMP         21
# DO           59
# TURB         97
# COND          6
# VEL       11051
# SS           19
# WDP          52
# CHLcal      524
# SECCHI       75
# dtype: int64

# %% [markdown]
# How much data is TDA ready?

# %%
water_filtered = water_data.dropna(axis=0, how='any', thresh=None, subset=continuous, inplace=False)

# %%
water_filtered.shape
# Out:
# (1946, 21)

# %%
water_data["YEAR"].value_counts().sort_index().plot()
plt.title("Number of Data Points by year")
# Out:
# Text(0.5, 1.0, 'Number of Data Points by year')

# %% [markdown]
# #### Interpolating missing data

# %%
missing_vars = ["TN","TP"]
water_interpolated = linear_interpolate(water_data,missing_vars)
# Out:
# Building a new dataframe with predicted values
# Appending predicted data for  1996    SUMMER
# Size of this year and season: (113, 21)
# Interpolating TN
# Interpolating TP
# Less than 2 locations have TP in this set, dropping rows without TP
# Current set is now  (0, 23)
# Appending predicted data for  1996    FALL
# Size of this year and season: (129, 21)
# Interpolating TN
# Interpolating TP
# Less than 2 locations have TP in this set, dropping rows without TP
# Current set is now  (0, 23)
# Appending predicted data for  1996    WINTER
# Size of this year and season: (10, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  1996    SPRING
# Size of this year and season: (0, 21)
# Interpolating TN
# Less than 2 locations have TN in this set, dropping rows without TN
# Current set is now  (0, 22)
# Interpolating TP
# Less than 2 locations have TP in this set, dropping rows without TP
# Current set is now  (0, 23)
# Appending predicted data for  1997    SUMMER
# Size of this year and season: (197, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  1997    FALL
# Size of this year and season: (203, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  1997    WINTER
# Size of this year and season: (188, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  1997    SPRING
# Size of this year and season: (189, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  1998    SUMMER
# Size of this year and season: (198, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  1998    FALL
# Size of this year and season: (196, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  1998    WINTER
# Size of this year and season: (198, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  1998    SPRING
# Size of this year and season: (199, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  1999    SUMMER
# Size of this year and season: (205, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  1999    FALL
# Size of this year and season: (137, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  1999    WINTER
# Size of this year and season: (185, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  1999    SPRING
# Size of this year and season: (157, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2000    SUMMER
# Size of this year and season: (203, 21)
# Interpolating TN
# Couldn't predict for  M066.3B
# [('M066.3B', 0.0, 2.234), ('M066.3B', 0.0, 3.7)]
# Interpolating TP
# Couldn't predict for  M066.3B
# [('M066.3B', 0.0, 0.199), ('M066.3B', 0.0, 0.332)]
# Appending predicted data for  2000    FALL
# Size of this year and season: (164, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2000    WINTER
# Size of this year and season: (98, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2000    SPRING
# Size of this year and season: (203, 21)
# Interpolating TN
# Couldn't predict for  M078.0B
# [('M078.0B', 0.0, 2.898), ('M078.0B', 0.0, 3.302)]
# Couldn't predict for  M070.2A
# [('M070.2A', 0.0, 2.466), ('M070.2A', 0.0, 2.974)]
# Couldn't predict for  M066.3A
# [('M066.3A', 0.0, 2.358), ('M066.3A', 0.0, 1.799)]
# Couldn't predict for  M066.3B
# [('M066.3B', 0.0, 3.781), ('M066.3B', 0.0, 2.621)]
# Couldn't predict for  BM00.7S
# [('BM00.7S', 0.0, 1.331), ('BM00.7S', 0.0, 1.189)]
# Couldn't predict for  M066.4C
# [('M066.4C', 0.0, 1.917), ('M066.4C', 0.0, 2.79)]
# Couldn't predict for  M059.5I
# [('M059.5I', 0.0, 2.698), ('M059.5I', 0.0, 2.439)]
# Couldn't predict for  HD00.9M
# [('HD00.9M', 0.0, 1.174), ('HD00.9M', 0.0, 0.303)]
# Interpolating TP
# Appending predicted data for  2001    SUMMER
# Size of this year and season: (202, 21)
# Interpolating TN
# Couldn't predict for  HD00.9M
# [('HD00.9M', 0.0, 1.777), ('HD00.9M', 0.0, 1.966)]
# Interpolating TP
# Appending predicted data for  2001    FALL
# Size of this year and season: (182, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2001    WINTER
# Size of this year and season: (135, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2001    SPRING
# Size of this year and season: (207, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2002    SUMMER
# Size of this year and season: (200, 21)
# Interpolating TN
# Couldn't predict for  M078.0B
# [('M078.0B', 0.0, 1.422), ('M078.0B', 0.0, 3.751)]
# Couldn't predict for  M066.3A
# [('M066.3A', 0.0, 1.528), ('M066.3A', 0.0, 1.305)]
# Interpolating TP
# Couldn't predict for  M059.5I
# [('M059.5I', 0.0, 0.18), ('M059.5I', 0.0, 0.091)]
# Couldn't predict for  BM00.7S
# [('BM00.7S', 0.0, 0.135), ('BM00.7S', 0.0, 0.165)]
# Couldn't predict for  M078.0B
# [('M078.0B', 0.0, 0.347), ('M078.0B', 0.0, 0.158)]
# Appending predicted data for  2002    FALL
# Size of this year and season: (18, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2002    WINTER
# Size of this year and season: (142, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2002    SPRING
# Size of this year and season: (213, 21)
# Interpolating TN
# Couldn't predict for  HD00.9M
# [('HD00.9M', 0.0, 1.158), ('HD00.9M', 0.0, 0.727)]
# Couldn't predict for  BM00.7S
# [('BM00.7S', 0.0, 1.156), ('BM00.7S', 0.0, 1.108)]
# Interpolating TP
# Appending predicted data for  2004    SUMMER
# Size of this year and season: (208, 21)
# Interpolating TN
# Couldn't predict for  M066.3B
# [('M066.3B', 0.0, 2.777), ('M066.3B', 0.0, 3.064)]
# Couldn't predict for  M066.3B
# [('M066.3B', 0.0, 2.777), ('M066.3B', 0.0, 3.064)]
# Interpolating TP
# Appending predicted data for  2004    FALL
# Size of this year and season: (156, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2004    WINTER
# Size of this year and season: (106, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2004    SPRING
# Size of this year and season: (184, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2005    SUMMER
# Size of this year and season: (142, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2005    FALL
# Size of this year and season: (151, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2005    WINTER
# Size of this year and season: (159, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2005    SPRING
# Size of this year and season: (195, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2006    SUMMER
# Size of this year and season: (152, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2006    FALL
# Size of this year and season: (127, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2006    WINTER
# Size of this year and season: (123, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2006    SPRING
# Size of this year and season: (193, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2007    SUMMER
# Size of this year and season: (194, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2007    FALL
# Size of this year and season: (173, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2007    WINTER
# Size of this year and season: (140, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2007    SPRING
# Size of this year and season: (195, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2008    SUMMER
# Size of this year and season: (186, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2008    FALL
# Size of this year and season: (164, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2008    WINTER
# Size of this year and season: (138, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2008    SPRING
# Size of this year and season: (204, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2009    SUMMER
# Size of this year and season: (191, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2009    FALL
# Size of this year and season: (175, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2009    WINTER
# Size of this year and season: (64, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2009    SPRING
# Size of this year and season: (194, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2010    SUMMER
# Size of this year and season: (192, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2010    FALL
# Size of this year and season: (177, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2010    WINTER
# Size of this year and season: (159, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2010    SPRING
# Size of this year and season: (195, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2011    SUMMER
# Size of this year and season: (195, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2011    FALL
# Size of this year and season: (159, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2011    WINTER
# Size of this year and season: (105, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2011    SPRING
# Size of this year and season: (194, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2012    SUMMER
# Size of this year and season: (155, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2012    FALL
# Size of this year and season: (99, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2012    WINTER
# Size of this year and season: (154, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2012    SPRING
# Size of this year and season: (200, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2013    SUMMER
# Size of this year and season: (172, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2013    FALL
# Size of this year and season: (108, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2013    WINTER
# Size of this year and season: (97, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2013    SPRING
# Size of this year and season: (193, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2014    SUMMER
# Size of this year and season: (195, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2014    FALL
# Size of this year and season: (176, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2014    WINTER
# Size of this year and season: (18, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2014    SPRING
# Size of this year and season: (193, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2015    SUMMER
# Size of this year and season: (195, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2015    FALL
# Size of this year and season: (131, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2015    WINTER
# Size of this year and season: (128, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2015    SPRING
# Size of this year and season: (189, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2016    SUMMER
# Size of this year and season: (186, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2016    FALL
# Size of this year and season: (176, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2016    WINTER
# Size of this year and season: (159, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2016    SPRING
# Size of this year and season: (204, 21)
# Interpolating TN
# Couldn't predict for  M070.2A
# [('M070.2A', 0.0, 4.576), ('M070.2A', 0.0, 5.458)]
# Interpolating TP
# Couldn't predict for  M070.2A
# [('M070.2A', 0.0, 0.15), ('M070.2A', 0.0, 0.152)]
# Appending predicted data for  2017    SUMMER
# Size of this year and season: (186, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2017    FALL
# Size of this year and season: (173, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2017    WINTER
# Size of this year and season: (158, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2017    SPRING
# Size of this year and season: (204, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2018    SUMMER
# Size of this year and season: (186, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2018    FALL
# Size of this year and season: (177, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2018    WINTER
# Size of this year and season: (126, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2018    SPRING
# Size of this year and season: (204, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2019    SUMMER
# Size of this year and season: (183, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2019    FALL
# Size of this year and season: (183, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2019    WINTER
# Size of this year and season: (159, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2019    SPRING
# Size of this year and season: (204, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2020    SUMMER
# Size of this year and season: (204, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2020    FALL
# Size of this year and season: (180, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2020    WINTER
# Size of this year and season: (161, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2020    SPRING
# Size of this year and season: (183, 21)
# Interpolating TN
# Interpolating TP
# Final data set size is  (15518, 23)
# Interpolating took 25.207410697142283 minutes

# %% [markdown]
# Save the interpolated dataset

# %%
pickle.dump(water_interpolated, open( "open_river_interpolated(TN,TP).p", "wb" ) )

# %% [markdown]
# Now see how many rows we gained after interpolation, and dropping VEL as a variable

# %%
used = ['PredictedTN','PredictedTP','TEMP','DO','TURB','COND','SS','WDP','CHLcal','SECCHI']

water_filtered_interpolated = water_interpolated.dropna(axis=0, how='any', thresh=None, subset=used, inplace=False)
water_filtered_interpolated.shape
# Out:
# (14789, 23)

# %% [markdown]
# Checking how good we did with prediction, first we need to filter the data based off values we already have

# %%
water_test = water_data[water_data["TN"].notna() & water_data["TP"].notna() & water_data["STRATUM"].notna()]
water_test.shape
# Out:
# (4668, 21)

# %%
missing_vars = ["TN","TP"]
water_test_interpolated = linear_interpolate(water_test,missing_vars,testing=True)
# Out:
# Building a new dataframe with predicted values
# Appending predicted data for  1997    WINTER
# Size of this year and season: (85, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  1997    SPRING
# Size of this year and season: (89, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  1997    SUMMER
# Size of this year and season: (83, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  1997    FALL
# Size of this year and season: (86, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  1998    WINTER
# Size of this year and season: (87, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  1998    SPRING
# Size of this year and season: (87, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  1998    SUMMER
# Size of this year and season: (87, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  1998    FALL
# Size of this year and season: (83, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  1999    WINTER
# Size of this year and season: (86, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  1999    SPRING
# Size of this year and season: (60, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  1999    SUMMER
# Size of this year and season: (81, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  1999    FALL
# Size of this year and season: (50, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2000    WINTER
# Size of this year and season: (32, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2000    SPRING
# Size of this year and season: (50, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2000    SUMMER
# Size of this year and season: (57, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2000    FALL
# Size of this year and season: (35, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2001    WINTER
# Size of this year and season: (31, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2001    SPRING
# Size of this year and season: (49, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2001    SUMMER
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2001    FALL
# Size of this year and season: (43, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2002    WINTER
# Size of this year and season: (43, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2002    SPRING
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2002    SUMMER
# Size of this year and season: (50, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2002    FALL
# Size of this year and season: (0, 21)
# Interpolating TN
# Less than 2 locations have TN in this set, dropping rows without TN
# Current set is now  (0, 22)
# Interpolating TP
# Less than 2 locations have TP in this set, dropping rows without TP
# Current set is now  (0, 23)
# Appending predicted data for  2004    WINTER
# Size of this year and season: (38, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2004    SPRING
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2004    SUMMER
# Size of this year and season: (50, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2004    FALL
# Size of this year and season: (42, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2005    WINTER
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2005    SPRING
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2005    SUMMER
# Size of this year and season: (34, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2005    FALL
# Size of this year and season: (42, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2006    WINTER
# Size of this year and season: (41, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2006    SPRING
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2006    SUMMER
# Size of this year and season: (42, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2006    FALL
# Size of this year and season: (36, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2007    WINTER
# Size of this year and season: (46, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2007    SPRING
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2007    SUMMER
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2007    FALL
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2008    WINTER
# Size of this year and season: (42, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2008    SPRING
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2008    SUMMER
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2008    FALL
# Size of this year and season: (46, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2009    WINTER
# Size of this year and season: (21, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2009    SPRING
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2009    SUMMER
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2009    FALL
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2010    WINTER
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2010    SPRING
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2010    SUMMER
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2010    FALL
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2011    WINTER
# Size of this year and season: (33, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2011    SPRING
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2011    SUMMER
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2011    FALL
# Size of this year and season: (47, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2012    WINTER
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2012    SPRING
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2012    SUMMER
# Size of this year and season: (43, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2012    FALL
# Size of this year and season: (29, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2013    WINTER
# Size of this year and season: (35, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2013    SPRING
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2013    SUMMER
# Size of this year and season: (46, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2013    FALL
# Size of this year and season: (30, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2014    WINTER
# Size of this year and season: (7, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2014    SPRING
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2014    SUMMER
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2014    FALL
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2015    WINTER
# Size of this year and season: (40, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2015    SPRING
# Size of this year and season: (49, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2015    SUMMER
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2015    FALL
# Size of this year and season: (39, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2016    WINTER
# Size of this year and season: (50, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2016    SPRING
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2016    SUMMER
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2016    FALL
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2017    WINTER
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2017    SPRING
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2017    SUMMER
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2017    FALL
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2018    WINTER
# Size of this year and season: (46, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2018    SPRING
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2018    SUMMER
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2018    FALL
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2019    WINTER
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2019    SPRING
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2019    SUMMER
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2019    FALL
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2020    WINTER
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2020    SPRING
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2020    SUMMER
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Appending predicted data for  2020    FALL
# Size of this year and season: (52, 21)
# Interpolating TN
# Interpolating TP
# Final data set size is  (4668, 23)
# Interpolating took 2.58673011859258 minutes

# %%
water_test_interpolated["TP error"] = abs(water_test_interpolated["PredictedTP"] - water_test_interpolated["TP"])
water_test_interpolated["TN error"] = abs(water_test_interpolated["PredictedTN"] - water_test_interpolated["TN"])
avg_TN_error = np.mean(water_test_interpolated["TN error"])
avg_TP_error = np.mean(water_test_interpolated["TP error"])

print(f"Average TN error {avg_TN_error:.5f}")
print(f"Average TP error {avg_TP_error:.5f}")
water_test_interpolated[["TP error","TN error"]].describe()
# Out:
# Average TN error 0.17985
# Average TP error 0.03250
#           TP error      TN error
# count  4668.000000  4.668000e+03
# mean      0.032496  1.798543e-01
# std       0.049788  4.635322e-01
# min       0.000000  6.030957e-08
# 25%       0.007000  4.333448e-02
# 50%       0.017016  9.552556e-02
# 75%       0.038683  1.898795e-01
# max       0.807285  1.899994e+01
