# %% [markdown]
# ### Imports and function declaration

# %%
import pandas as pd
import pickle
import os
import matplotlib.pyplot as plt
import numpy as np
from geopy import distance
import time
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import RobustScaler,StandardScaler
from sklearn.preprocessing import PolynomialFeatures
pd.set_option('display.max_columns', None)

# useful functions and classes

# This class stores the latitude and longitude of a sample, and indicates 
# if this location has the desired variable we are estimating
class Location:
    def __init__(self,latitude,longitude,hasv,ID,value):
        self.ID = ID
        self.latitude = latitude
        self.longitude = longitude
        self.hasv = hasv
        self.value = value
        
    def __str__(self):
        return str(self.ID)

# Calculates the distance between 2 samples in km
def getdist(S1,S2):
    # radius of earth in km
    coords_1 = (S1.latitude, S1.longitude)
    coords_2 = (S2.latitude, S2.longitude)
    dist = distance.distance(coords_1, coords_2).km
    return dist

# filters out data if a point is missing in one of the colunns
def filterblanks(columns,data,blank):
    # if blank is true, remove rows with blanks in these columns
    # if blank is false, remove rows with non blanks or non zeros in these columns
    for c in columns:
        if blank:
            data = data[data[c].notnull()].copy()
        else:
            data = data[data[c].isnull()].copy()
    return data

# PRE: all locations in the dataframe are
# unique
def DistanceMatrix(dataframe,variable):
    numunique = len(dataframe["LOCATCD"].unique())
    numlocations = dataframe.shape[0]
    try:
        assert(numunique == numlocations), f"{numunique} unique locations but {numlocations} number of locations"
    
    except AssertionError as msg:
        display(dataframe[dataframe["LOCATCD"].duplicated(keep=False)])
        print(msg)
        
    # the list of location objects
    locations = []
    # the list of indexes where the the row is located in the dataframe
    #indexes = []
    for index,row in dataframe.iterrows():
        # make a location object on this row
        if pd.isnull(row[variable]):
            hasv = False
        else:
            hasv = True
        locations.append(Location(row["LATITUDE"],row["LONGITUDE"],hasv,row["LOCATCD"],row[variable]))
        #indexes.append(index)
        
    matrix = pd.DataFrame(0,index=locations,columns=locations)
    for ci,column in enumerate(locations):
        for ri,row in enumerate(locations):
            if ri>ci:
                # compute distance between column and row
                dist = getdist(row,column)
            elif ci>ri:
                dist = matrix.iloc[ci,ri]
            # put this distance in the dataframe
            else:
                continue
            matrix.iloc[ri,ci] = dist
    return matrix

def changeVar(DM,dataframe,variable):
    locations = DM.index
    # loop through each location
    for i,loc in enumerate(locations):
        ID = loc.ID
        row = dataframe[dataframe["LOCATCD"]==ID]
        
        try:
            assert(row.shape[0]==1), "Multiple rows with same LOCATCD"
        except AssertionError as msg:
            display(dataframe[dataframe["LOCATCD"].duplicated(keep=False)])
            print(msg)
            
        #print(row)
        #print(row.shape)
        #print(row[variable])
        #print(row[variable].isnull().values)
        # check None vs nan on python
        if pd.isnull(row[variable]).bool():
            locations[i].hasv = False
            locations[i].value = None
        else:
            locations[i].hasv = True
            locations[i].value = row[variable]
            
    DM.index = locations
    DM.columns = locations
        
def getclosest(numclosest,distancematrix,location,testing):
    column = distancematrix.loc[:,location].copy()
    #print(type(distancematrix.index[0]))
    # Filter the locations that dont have the desired variable
    doesnthavev = []
    for i in range(len(column)):
        if not column.index[i].hasv:
            doesnthavev.append(column.index[i])
    column.drop(doesnthavev,inplace = True)
    #print(type(column))
    column.sort_values(inplace = True)
    # Are we predicting for a value we already have?
    if testing:
        return column.iloc[1:numclosest+1]
    else:
        return column.iloc[0:numclosest]

# Key: Location Code
# Value: List of tuples (locatcd,distance,value)
def makeDict(DM,numclosest,testing):
    # Loop through each location without a value for variable
    closestDict = {}
    for loc in DM.columns:
        if not loc.hasv or testing:
            # Get the closest locations to loc THAT ISN'T LOC
            closest = getclosest(numclosest,DM,loc,testing)
            # The list of tuples that contain location id, the distance, and the value for variable
            tuples = []
            for i,dist in enumerate(closest):
                ID = closest.index[i].ID
                val = closest.index[i].value
                tuples.append((ID,dist,val))
            closestDict[loc.ID] = tuples
    return closestDict

def predict(tuples,numclosest = 2):
    loc2 = tuples[0]
    loc3 = tuples[1]
    d12 = loc2[1]
    val2 = loc2[2]
    d13 = loc3[1]
    val3 = loc3[2]
    
    c2 = d12/(d12+d13)
    c3 = d13/(d12+d13)
    
    predicted = c2*val2+c3*val3
    
    return predicted

# NEEDS WORK
def addpredictions(df,variables,numclosest):
    # make prediction and insert for each variable
    first = True
    for var in variables:
        if first:
            DM = DistanceMatrix(df,var)
        else:
            changeVar(DM,df,var)
            
        for loc in DM.columns:
            if not loc.hasv:
                # Get the closest locations to loc
                closest = getclosest(numclosest,DM,loc)
                # The list of tuples that contain location id, the distance, and the value for variable
                tuples = []
                for i,dist in enumerate(closest):
                    ID = closest.index[i].ID
                    val = closest.index[i].value
                    tuples.append((ID,dist,val))
                closestDict[loc.ID] = tuples

        
'''
data - the pandas dataframe that is ready to interpolate missing values
MUST HAVE "LATITUDE", "LONGITUDE","YEAR", "TIME CODE", "LOCATCD" columns

missing_vars - the list of column names (as strings) of the dataframe that we should attempt to fill in

numlocations - the number of locations used to predict the new value, default is 2 (currently the only option implemented)

RETURN - a dataframe with extra columns saying the predicted values of the missing_vars
'''
def linear_interpolate(data,missing_vars,numlocations = 2,testing = False):
    print("Building a new dataframe with predicted values")
    start_time = time.time()
    # Testing for duplicated locations if needed
    #s = qualdata_noprediction["LOCATCD"].duplicated(keep=False)
    # get the years and timecodes for this dataset
    # predictions can only be made if the point is in the same year and time code (what if we don't need to do this)
    years = data["YEAR"].unique()
    seasons = data["SEASON"].unique()
    data_prediction = pd.DataFrame()
    for year in years:
        for season in seasons:
            print("Appending predicted data for ",year,"  ",season)
            # curset is the current set of rows we are predicting for
            curset = data[(data["YEAR"]==year) & (data["SEASON"]==season)].copy()
            print("Size of this year and season:", curset.shape)
            
            # Boolean to indicate if variable in Distance matrix needs updating
            first = True
            for var in missing_vars:
                print("Interpolating "+var)
                newcolumn = "Predicted"+var
                curset[newcolumn] = 0
            
                #check to see if there are enough valid locations
                # that can be used to predict
                if not testing:
                    bad = bool((curset[var].notnull().sum()<numlocations))
                else:
                    bad = bool((curset[var].notnull().sum()<numlocations+1))
                

                if(bad):
                    print("Less than "+str(numlocations)+" locations have "+var+" in this set, dropping rows without "+var)
                    curset = curset[curset[var].notnull()]
                    curset[newcolumn] = curset[var]
                    print("Current set is now ",curset.shape)
                else:
                    if first:
                        DM = DistanceMatrix(curset,var)
                        first = False
                    else:
                        changeVar(DM,curset,var)
                        
                    # Returns a dictionary mapping each location code to a tuple with prediction information
                    Dict = makeDict(DM,numlocations,testing)
                    
                    #put in predicted variable
                    for index,row in curset.iterrows():
                        if pd.isnull(row[var]).bool() or testing:
                            try:
                                curset.loc[index,newcolumn] = predict(Dict[row["LOCATCD"]])
                            except ZeroDivisionError:
                                print("Couldn't predict for ", str(row["LOCATCD"]))
                                print(Dict[row["LOCATCD"]])
                                curset.loc[index,newcolumn] = None
                        else:
                            curset.loc[index,newcolumn] = row[var]

            data_prediction = data_prediction.append(curset,ignore_index=True)  
            
    print("Final data set size is ",data_prediction.shape)
    print(f"Interpolating took {(time.time()-start_time)/60} minutes")
    return data_prediction

# %% [markdown]
# ### Loading and Filtering data

# %%
water_path = r"..\..\LTRM data\water_data_qfneg.csv"
water_data = pd.read_csv(water_path, low_memory = False)
veg_path = r"..\..\LTRM data\ltrm_vegsrs_data_lat_long.csv"
veg_data = pd.read_csv(veg_path, low_memory = False)

continuous = ['TN','TP','TEMP','DO','TURB','COND','VEL','SS','WDP','CHLcal','SECCHI']
seasons = {3:"SPRING",4:"SPRING",5:"SPRING",6:"SUMMER",7:"SUMMER",8:"SUMMER",9:"FALL",10:"FALL",11:"FALL",12:"WINTER",1:"WINTER",2:"WINTER"}

print("Now adding a year column")
water_data["YEAR"] = pd.DatetimeIndex(water_data["DATE"]).year
print("Now adding a month column")
water_data["MONTH"] = pd.DatetimeIndex(water_data["DATE"]).month
print("Now adding a season column")
water_data["SEASON"] = water_data["MONTH"]
water_data = water_data.replace({"SEASON":seasons})

print("Veg data")
print(veg_data.columns)
print(veg_data.shape)

print("\n\n Water data")
print(water_data.columns)
print(water_data.shape)

print("Filtering by pool")
veg_data = veg_data[veg_data["FLDNUM"]==5].reset_index(drop=True)
water_data = water_data[water_data["FLDNUM"]==5].reset_index(drop=True)
print(veg_data.shape)
print(water_data.shape)
# Out:
# Now adding a year column
# Now adding a month column
# Now adding a season column
# Veg data
# Index(['BARCODE', 'ROWNUM', 'PAGENUM', 'FLDNUM', 'PROJCD', 'POOL', 'DATE',
#        'LDRCODE', 'RCRDCODE', 'DETRITUS', 'SBSTRATE', 'SITECD', 'MSTRATUM',
#        'ASTRATUM', 'RIVMILE', 'VEG_S', 'VEG_RF', 'VEG_E', 'VEG_A', 'VEG_NRF',
#        'VEG_U', 'COV_NRF', 'COV_RF', 'COV_E', 'EAST1', 'NORTH1', 'ZONE',
#        'ACCUR1', 'METHOD', 'EAST2', 'NORTH2', 'ACCUR2', 'ZONE_U', 'EAST_U',
#        'NORTH_U', 'GRIDCODE', 'EAST_15', 'NORTH_15', 'HABITAT1', 'HABITAT2',
#        'HABITAT3', 'HABITAT4', 'HABITAT5', 'HABITAT6', 'DEPTH1', 'DEPTH2',
#        'DEPTH3', 'DEPTH4', 'DEPTH5', 'DEPTH6', 'DENSITY1', 'DENSITY2',
#        'DENSITY3', 'DENSITY4', 'DENSITY5', 'DENSITY6', 'BATCHNUM', 'SPPCD',
#        'VISUAL1', 'VISUAL2', 'VISUAL3', 'VISUAL4', 'VISUAL5', 'VISUAL6',
#        'RAKE1', 'RAKE2', 'RAKE3', 'RAKE4', 'RAKE5', 'RAKE6', 'ADDSPP',
#        'COVSPP', 'QECODE', 'VOUCHER', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')
# (125063, 76)
#
#
#  Water data
# Index(['SHEETBAR', 'DATE', 'LATITUDE', 'LONGITUDE', 'FLDNUM', 'STRATUM',
#        'LOCATCD', 'TN', 'TP', 'TEMP', 'DO', 'TURB', 'COND', 'VEL', 'SS', 'WDP',
#        'CHLcal', 'SECCHI', 'YEAR', 'MONTH', 'SEASON'],
#       dtype='object')
# (82481, 21)
# Filtering by pool
# (0, 76)
# (14200, 21)

# %%
df = pd.DataFrame([[1, None], [4, 5], [7, 8]],
     index=['cobra', 'viper', 'sidewinder'],
     columns=['max_speed', 'shield'])
df
# Out:
#             max_speed  shield
# cobra               1     NaN
# viper               4     5.0
# sidewinder          7     8.0

# %%
row = df[df["max_speed"]==1]
row
# Out:
#        max_speed  shield
# cobra          1     NaN

# %%
pd.isnull(row["shield"]).bool()
# Out:
# True

# %%
water_data.head()
# Out:
#    SHEETBAR        DATE  LATITUDE  LONGITUDE  FLDNUM  STRATUM  LOCATCD     TN  \
# 0  45000007  09/15/1993  37.32989  -89.47505       5        2  9353150    NaN
# 1  45000008  09/15/1993  37.32201  -89.45285       5        2  9353152    NaN
# 2  45000009  09/15/1993  37.37297  -89.40981       5        2  9353048  3.376
# 3  45000010  09/15/1993  37.32701  -89.43908       5        2  9353151    NaN
# 4  45000011  09/15/1993  37.32995  -89.47730       5        2  9353149    NaN
#
#       TP  TEMP   DO  TURB   COND  VEL     SS   WDP   CHLcal  SECCHI  YEAR  \
# 0    NaN  20.7  7.3  69.0  463.0  NaN  125.0  16.1  8.45574    16.0  1993
# 1    NaN  20.6  7.4  66.0  465.0  NaN  121.8  11.5  9.67430    16.0  1993
# 2  0.339  21.0  7.3  64.0  480.0  NaN  105.3  10.5  9.06502    14.0  1993
# 3    NaN  20.7  7.3  66.0  470.0  NaN  127.2   9.9  9.50022    16.0  1993
# 4    NaN  20.6  7.3  65.0  463.0  NaN  117.8   8.3  8.80390    16.0  1993
#
#    MONTH SEASON
# 0      9   FALL
# 1      9   FALL
# 2      9   FALL
# 3      9   FALL
# 4      9   FALL

# %% [markdown]
# Checking negative values

# %%
(water_data[continuous] < 0).sum()
# Out:
# TN        0
# TP        0
# TEMP      0
# DO        0
# TURB      0
# COND      0
# VEL       0
# SS        0
# WDP       0
# CHLcal    0
# SECCHI    0
# dtype: int64

# %% [markdown]
# Checking for weird location codes

# %%
num_weird = 0
for index,row in water_data.iterrows():
    if not str(row["LOCATCD"]).isnumeric():
        num_weird += 1
        #print(row["LOCATCD"],row["YEAR"])
print(num_weird)
# Out:
# 0

# %% [markdown]
# Insanity check for time seasons

# %%
water_data["SEASON"].unique()
# Out:
# array(['FALL', 'WINTER', 'SPRING', 'SUMMER'], dtype=object)

# %% [markdown]
# #### Checking stratum data size

# %%
water_data["STRATUM"].unique()
# Out:
# array([2, 1], dtype=int64)

# %%
water_data[water_data["STRATUM"].isna()]
# Out:
# Empty DataFrame
# Columns: [SHEETBAR, DATE, LATITUDE, LONGITUDE, FLDNUM, STRATUM, LOCATCD, TN, TP, TEMP, DO, TURB, COND, VEL, SS, WDP, CHLcal, SECCHI, YEAR, MONTH, SEASON]
# Index: []

# %%
sum(water_data["STRATUM"] == 1)
# Out:
# 7640

# %%
sum(water_data["STRATUM"]==2)
# Out:
# 6560

# %% [markdown]
# #### Taking a look at our variables

# %%
water_data[continuous].describe()
# Out:
#                 TN           TP          TEMP            DO          TURB  \
# count  5650.000000  5485.000000  14096.000000  14063.000000  13972.000000
# mean      2.944235     0.251671     16.521283      8.995762    104.876038
# std       1.230136     0.118396      9.440878      2.716562    107.388126
# min       0.220000     0.005000      0.000000      0.000000      3.000000
# 25%       2.252000     0.181000     12.700000      7.000000     40.000000
# 50%       2.917000     0.230000     16.900000      8.300000     75.000000
# 75%       3.528000     0.298000     26.000000     10.300000    125.000000
# max      32.965000     3.500000     34.000000     25.000000   1330.000000
#
#                COND          VEL            SS           WDP        CHLcal  \
# count  14087.000000  4413.000000  13834.000000  13719.000000  14037.000000
# mean     530.615816     0.750376    146.833897      7.069427     17.798307
# std       83.961121     0.459998    144.560175      4.099851     12.335497
# min      168.000000     0.000000      1.600000      0.200000      0.153880
# 25%      468.000000     0.390000     56.800000      4.000000      9.332200
# 50%      531.000000     0.750000    104.400000      6.500000     14.484000
# 75%      588.000000     1.080000    183.092500      9.600000     22.868200
# max      970.000000     2.270000   1439.600000     40.200000    151.036300
#
#              SECCHI
# count  13255.000000
# mean      23.878084
# std       13.076579
# min        1.000000
# 25%       14.000000
# 50%       21.000000
# 75%       30.000000
# max      250.000000

# %% [markdown]
# #### Boxplots and histograms

# %%
var = "TP"
water_data[[var,'STRATUM']].boxplot(by='STRATUM', meanline=True, showmeans=True, showcaps=True, 
                showbox=True, showfliers=True,return_type = 'axes')
plt.suptitle('') # that's what you're after
plt.show()

# %%
water_data[[var,'STRATUM']].hist(by='STRATUM')
plt.suptitle(var) # that's what you're after
# Out:
# Text(0.5, 0.98, 'TP')

# %% [markdown]
# #### Missing data

# %%
water_data[continuous].isnull().sum()
# Out:
# TN        8550
# TP        8715
# TEMP       104
# DO         137
# TURB       228
# COND       113
# VEL       9787
# SS         366
# WDP        481
# CHLcal     163
# SECCHI     945
# dtype: int64

# %% [markdown]
# How much data is TDA ready?

# %%
water_filtered = water_data.dropna(axis=0, how='any', thresh=None, subset=continuous, inplace=False)

# %%
water_filtered.shape
# Out:
# (1508, 21)

# %%
water_data["YEAR"].value_counts().sort_index().plot()
plt.title("Number of Data Points by year")
# Out:
# Text(0.5, 1.0, 'Number of Data Points by year')

# %% [markdown]
# #### Interpolating missing data

# %%
missing_vars = ["TN","TP","VEL"]
water_interpolated = linear_interpolate(water_data,missing_vars)
# Out:
# Building a new dataframe with predicted values
# Appending predicted data for  1993    FALL
# Size of this year and season: (150, 21)
# Interpolating TN
# Interpolating TP
#    SHEETBAR        DATE  LATITUDE  LONGITUDE  FLDNUM  STRATUM  LOCATCD  TN  \
# 0  45000007  09/15/1993  37.32989  -89.47505       5        2  9353150 NaN
#
#    TP  TEMP   DO  TURB   COND  VEL     SS   WDP   CHLcal  SECCHI  YEAR  MONTH  \
# 0 NaN  20.7  7.3  69.0  463.0  NaN  125.0  16.1  8.45574    16.0  1993      9
#
#   SEASON  PredictedTN  PredictedTP
# 0   FALL     3.563516            0
# (1, 23)
# 0   NaN
# Name: TP, dtype: float64
# [ True]
#    SHEETBAR        DATE  LATITUDE  LONGITUDE  FLDNUM  STRATUM  LOCATCD  TN  \
# 1  45000008  09/15/1993  37.32201  -89.45285       5        2  9353152 NaN
#
#    TP  TEMP   DO  TURB   COND  VEL     SS   WDP  CHLcal  SECCHI  YEAR  MONTH  \
# 1 NaN  20.6  7.4  66.0  465.0  NaN  121.8  11.5  9.6743    16.0  1993      9
#
#   SEASON  PredictedTN  PredictedTP
# 1   FALL     3.538728            0
# (1, 23)
# 1   NaN
# Name: TP, dtype: float64
# [ True]
#    SHEETBAR        DATE  LATITUDE  LONGITUDE  FLDNUM  STRATUM  LOCATCD     TN  \
# 2  45000009  09/15/1993  37.37297  -89.40981       5        2  9353048  3.376
#
#       TP  TEMP   DO  TURB   COND  VEL     SS   WDP   CHLcal  SECCHI  YEAR  \
# 2  0.339  21.0  7.3  64.0  480.0  NaN  105.3  10.5  9.06502    14.0  1993
#
#    MONTH SEASON  PredictedTN  PredictedTP
# 2      9   FALL        3.376            0
# (1, 23)
# 2    0.339
# Name: TP, dtype: float64
# [False]
#    SHEETBAR        DATE  LATITUDE  LONGITUDE  FLDNUM  STRATUM  LOCATCD  TN  \
# 3  45000010  09/15/1993  37.32701  -89.43908       5        2  9353151 NaN
#
#    TP  TEMP   DO  TURB   COND  VEL     SS  WDP   CHLcal  SECCHI  YEAR  MONTH  \
# 3 NaN  20.7  7.3  66.0  470.0  NaN  127.2  9.9  9.50022    16.0  1993      9
#
#   SEASON  PredictedTN  PredictedTP
# 3   FALL     3.556821            0
# (1, 23)
# 3   NaN
# Name: TP, dtype: float64
# [ True]
#    SHEETBAR        DATE  LATITUDE  LONGITUDE  FLDNUM  STRATUM  LOCATCD  TN  \
# 4  45000011  09/15/1993  37.32995   -89.4773       5        2  9353149 NaN
#
#    TP  TEMP   DO  TURB   COND  VEL     SS  WDP  CHLcal  SECCHI  YEAR  MONTH  \
# 4 NaN  20.6  7.3  65.0  463.0  NaN  117.8  8.3  8.8039    16.0  1993      9
#
#   SEASON  PredictedTN  PredictedTP
# 4   FALL     3.568435            0
# (1, 23)
# 4   NaN
# Name: TP, dtype: float64
# [ True]
#    SHEETBAR        DATE  LATITUDE  LONGITUDE  FLDNUM  STRATUM  LOCATCD  TN  \
# 5  45000013  09/15/1993  37.36411  -89.41475       5        2  9353146 NaN
#
#    TP  TEMP   DO  TURB   COND  VEL     SS  WDP   CHLcal  SECCHI  YEAR  MONTH  \
# 5 NaN  20.7  7.3  62.0  484.0  NaN  107.7  9.9  9.15206    16.0  1993      9
#
#   SEASON  PredictedTN  PredictedTP
# 5   FALL      3.40533            0
# (1, 23)
# 5   NaN
# Name: TP, dtype: float64
# [ True]
#    SHEETBAR        DATE  LATITUDE  LONGITUDE  FLDNUM  STRATUM  LOCATCD  TN  \
# 6  45000014  09/15/1993  37.37664  -89.41189       5        2  9353144 NaN
#
#    TP  TEMP   DO  TURB   COND  VEL     SS   WDP   CHLcal  SECCHI  YEAR  MONTH  \
# 6 NaN  21.0  7.4  68.0  468.0  NaN  121.4  10.7  9.93542    15.0  1993      9
#
#   SEASON  PredictedTN  PredictedTP
# 6   FALL     3.414158            0
# (1, 23)
# 6   NaN
# Name: TP, dtype: float64
# [ True]
#    SHEETBAR        DATE  LATITUDE  LONGITUDE  FLDNUM  STRATUM  LOCATCD     TN  \
# 7  45000015  09/15/1993  37.34992   -89.4222       5        2  9353052  3.611
#
#       TP  TEMP   DO  TURB   COND  VEL     SS   WDP   CHLcal  SECCHI  YEAR  \
# 7  0.349  20.7  7.4  63.0  465.0  NaN  105.5  10.6  8.19462    14.0  1993
#
#    MONTH SEASON  PredictedTN  PredictedTP
# 7      9   FALL        3.611            0
# (1, 23)
# 7    0.349
# Name: TP, dtype: float64
# [False]
#    SHEETBAR        DATE  LATITUDE  LONGITUDE  FLDNUM  STRATUM  LOCATCD  TN  \
# 8  45000016  09/15/1993  37.39877  -89.42891       5        2  9353142 NaN
#
#    TP  TEMP   DO  TURB   COND  VEL     SS  WDP    CHLcal  SECCHI  YEAR  MONTH  \
# 8 NaN  21.2  7.2  76.0  480.0  NaN  154.0  8.2  10.19654    15.0  1993      9
#
#   SEASON  PredictedTN  PredictedTP
# 8   FALL      3.37032            0
# (1, 23)
# 8   NaN
# Name: TP, dtype: float64
# [ True]
#    SHEETBAR        DATE  LATITUDE  LONGITUDE  FLDNUM  STRATUM  LOCATCD  TN  \
#
NaN
# Name: TP, dtype: float64
# [ True]
#      SHEETBAR        DATE  LATITUDE  LONGITUDE  FLDNUM  STRATUM  LOCATCD  \
# 141  45000155  09/22/1993  37.12938  -89.39885       5        2  9353074
#
#         TN     TP  TEMP   DO  TURB   COND  VEL     SS  WDP   CHLcal  SECCHI  \
# 141  3.443  0.311  19.2  7.8  81.0  418.0  NaN  160.4  5.0  8.28166    15.0
#
#      YEAR  MONTH SEASON  PredictedTN  PredictedTP
# 141  1993      9   FALL        3.443            0
# (1, 23)
# 141    0.311
# Name: TP, dtype: float64
# [False]
#      SHEETBAR        DATE  LATITUDE  LONGITUDE  FLDNUM  STRATUM  LOCATCD  TN  \
# 142  45000156  09/22/1993  37.02911   -89.3609       5        1  9353135 NaN
#
#      TP  TEMP   DO  TURB   COND  VEL     SS   WDP   CHLcal  SECCHI  YEAR  \
# 142 NaN  19.3  7.6  81.0  410.0  NaN  177.1  15.0  8.54278    14.0  1993
#
#      MONTH SEASON  PredictedTN  PredictedTP
# 142      9   FALL     3.315387            0
# (1, 23)
# 142   NaN
# Name: TP, dtype: float64
# [ True]
#      SHEETBAR        DATE  LATITUDE  LONGITUDE  FLDNUM  STRATUM  LOCATCD  \
# 143  45000157  09/22/1993  37.12572  -89.39677       5        2  9353076
#
#         TN     TP  TEMP   DO  TURB   COND  VEL     SS  WDP   CHLcal  SECCHI  \
# 143  3.366  0.356  19.4  7.7  76.0  415.0  NaN  139.1  6.1  8.97798    15.0
#
#      YEAR  MONTH SEASON  PredictedTN  PredictedTP
# 143  1993      9   FALL        3.366            0
# (1, 23)
# 143    0.356
# Name: TP, dtype: float64
# [False]
#      SHEETBAR        DATE  LATITUDE  LONGITUDE  FLDNUM  STRATUM  LOCATCD  TN  \
# 144  45000158  09/22/1993  37.08178  -89.37412       5        1  9353131 NaN
#
#      TP  TEMP   DO  TURB   COND  VEL     SS   WDP    CHLcal  SECCHI  YEAR  \
# 144 NaN  19.3  7.8  82.0  413.0  NaN  178.2  40.2  10.02246    14.0  1993
#
#      MONTH SEASON  PredictedTN  PredictedTP
# 144      9   FALL     3.648326            0
# (1, 23)
# 144   NaN
# Name: TP, dtype: float64
# [ True]
#      SHEETBAR        DATE  LATITUDE  LONGITUDE  FLDNUM  STRATUM  LOCATCD  TN  \
# 145  45000159  09/22/1993  37.04039  -89.37609       5        1  9353133 NaN
#
#      TP  TEMP   DO  TURB   COND  VEL     SS  WDP   CHLcal  SECCHI  YEAR  \
# 145 NaN  19.5  7.8  82.0  424.0  NaN  179.9  1.6  9.50022    15.0  1993
#
#      MONTH SEASON  PredictedTN  PredictedTP
# 145      9   FALL     3.321119            0
# (1, 23)
# 145   NaN
# Name: TP, dtype: float64
# [ True]
#      SHEETBAR        DATE  LATITUDE  LONGITUDE  FLDNUM  STRATUM  LOCATCD  \
# 146  45000160  09/22/1993  37.07652  -89.37887       5        1  9353038
#
#         TN     TP  TEMP   DO  TURB   COND  VEL     SS  WDP  CHLcal  SECCHI  \
# 146  3.672  0.343  19.4  7.6  86.0  415.0  NaN  190.8  6.6  9.6743    14.0
#
#      YEAR  MONTH SEASON  PredictedTN  PredictedTP
# 146  1993      9   FALL        3.672            0
# (1, 23)
# 146    0.343
# Name: TP, dtype: float64
# [False]
#      SHEETBAR        DATE  LATITUDE  LONGITUDE  FLDNUM  STRATUM  LOCATCD  \
# 147  45000161  09/22/1993  37.13672    -89.403       5        2  9353070
#
#        TN     TP  TEMP   DO  TURB   COND  VEL     SS  WDP    CHLcal  SECCHI  \
# 147  3.14  0.341  19.3  7.8  77.0  417.0  NaN  175.4  8.3  10.37062    14.0
#
#      YEAR  MONTH SEASON  PredictedTN  PredictedTP
# 147  1993      9   FALL         3.14            0
# (1, 23)
# 147    0.341
# Name: TP, dtype: float64
# [False]
#      SHEETBAR        DATE  LATITUDE  LONGITUDE  FLDNUM  STRATUM  LOCATCD  \
# 148  45000162  09/22/1993  37.06746  -89.37705       5        1  9353039
#
#         TN     TP  TEMP   DO  TURB   COND  VEL     SS  WDP   CHLcal  SECCHI  \
# 148  3.381  0.349  19.4  7.5  84.0  419.0  NaN  183.3  9.3  8.54278    13.0
#
#      YEAR  MONTH SEASON  PredictedTN  PredictedTP
# 148  1993      9   FALL        3.381            0
# (1, 23)
# 148    0.349
# Name: TP, dtype: float64
# [False]
#      SHEETBAR        DATE  LATITUDE  LONGITUDE  FLDNUM  STRATUM  LOCATCD  TN  \
# 149  45000163  09/22/1993  37.03838  -89.36944       5        2  9353170 NaN
#
#      TP  TEMP   DO  TURB   COND  VEL     SS  WDP  CHLcal  SECCHI  YEAR  MONTH  \
# 149 NaN  19.3  7.7  83.0  409.0  NaN  160.8  8.4  9.2391    14.0  1993      9
#
#     SEASON  PredictedTN  PredictedTP
# 149   FALL     3.317053            0
# (1, 23)
# 149   NaN
# Name: TP, dtype: float64
# [ True]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-982bc02397e7> in <module>
#       1 missing_vars = ["TN","TP","VEL"]
# ----> 2 water_interpolated = linear_interpolate(water_data,missing_vars)
#
# <ipython-input-14-30d1502586e4> in linear_interpolate(data, missing_vars, numlocations, testing)
#     247                         if pd.isnull(row[var]) or testing:
#     248                             try:
# --> 249                                 curset.loc[index,newcolumn] = predict(Dict[row["LOCATCD"]])
#     250                             except ZeroDivisionError:
#     251                                 print("Couldn't predict for ", str(row["LOCATCD"]))
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     690
#     691         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 692         iloc._setitem_with_indexer(indexer, value, self.name)
#     693
#     694     def _validate_key(self, key, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1633         if take_split_path:
#    1634             # We have to operate column-wise
# -> 1635             self._setitem_with_indexer_split_path(indexer, value, name)
#    1636         else:
#    1637             self._setitem_single_block(indexer, value, name)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer_split_path(self, indexer, value, name)
#    1652
#    1653         if isinstance(value, ABCSeries) and name != "iloc":
# -> 1654             value = self._align_series(indexer, value)
#    1655
#    1656         # Ensure we have something we can iterate over
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _align_series(self, indexer, ser, multiindex_indexer)
#    2028             return ser.reindex(ax)._values
#    2029
# -> 2030         raise ValueError("Incompatible indexer with Series")
#    2031
#    2032     def _align_frame(self, indexer, df: "DataFrame"):
#
# ValueError: Incompatible indexer with Series

# %% [markdown]
# Save the interpolated dataset

# %%
pickle.dump(water_interpolated, open( "open_river_interpolated(TN,TP).p", "wb" ) )

# %% [markdown]
# Now see how many rows we gained after interpolation, and dropping VEL as a variable

# %%
used = ['PredictedTN','PredictedTP','TEMP','DO','TURB','COND','SS','WDP','CHLcal','SECCHI']

water_filtered_interpolated = water_interpolated.dropna(axis=0, how='any', thresh=None, subset=used, inplace=False)
water_filtered_interpolated.shape
# Out:
# (14789, 23)

# %% [markdown]
# #### Checking how good we did with prediction, first we need to filter the data based off values we already have

# %%
water_data.head()
# Out:
#    Unnamed: 0  SHEETBAR     TN  TP  TEMP   DO   TURB   COND   VEL     SS  \
# 0       72964  45002343  3.989 NaN  27.7  6.1  153.0  565.0   NaN  247.7
# 1       72965  45002344  1.211 NaN  27.8  3.4   46.0  494.0  0.11   44.8
# 2       72966  45002345  4.022 NaN  27.6  5.9  174.0  564.0   NaN  209.5
# 3       72967  45002349  4.056 NaN  27.5  5.8   93.0  545.0  0.20  122.7
# 4       72968  45002350  4.028 NaN  27.6  6.0  151.0  563.0   NaN  201.3
#
#     WDP  CHLcal  SECCHI  LONGITUDE   LATITUDE        DATE  FLDNUM  LOCATCD  \
# 0   3.5     NaN    11.0 -89.512066  37.604644  07/09/1996       5  M078.0B
# 1   5.6     NaN    37.0 -89.509512  37.578378  07/09/1996       5  BM00.7S
# 2   5.0     NaN    11.0 -89.498738  37.498336  07/09/1996       5  M070.2A
# 3   4.0     NaN    12.0 -89.451772  37.455464  07/09/1996       5  M066.4C
# 4  12.5     NaN    13.0 -89.458085  37.455311  07/09/1996       5  M066.3B
#
#    STRATUM  YEAR  MONTH  SEASON
# 0      NaN  1996      7  SUMMER
# 1      NaN  1996      7  SUMMER
# 2      NaN  1996      7  SUMMER
# 3      NaN  1996      7  SUMMER
# 4      NaN  1996      7  SUMMER

# %%
water_test = water_data[water_data["TN"].notna() & water_data["TP"].notna() & water_data["STRATUM"].notna() & water_data["VEL"].notna()]
print(water_test.shape[0])
water_test[water_test["LOCATCD"].duplicated(keep = False)]
# Out:
# 1551
# Empty DataFrame
# Columns: [SHEETBAR, TN, TP, TEMP, DO, TURB, COND, VEL, SS, WDP, CHLcal, SECCHI, LONGITUDE, LATITUDE, DATE, FLDNUM, LOCATCD, STRATUM, YEAR, MONTH, SEASON]
# Index: []

# %%
missing_vars = ["TN","TP","VEL"]
water_test_interpolated = linear_interpolate(water_test,missing_vars,testing=True)
# Out:
# Building a new dataframe with predicted values
# Appending predicted data for  1997    WINTER
# Size of this year and season: (38, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for
 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for  2012    FALL
# Size of this year and season: (1, 21)
# Interpolating TN
# Less than 2 locations have TN in this set, dropping rows without TN
# Current set is now  (1, 22)
# Interpolating TP
# Less than 2 locations have TP in this set, dropping rows without TP
# Current set is now  (1, 23)
# Interpolating VEL
# Less than 2 locations have VEL in this set, dropping rows without VEL
# Current set is now  (1, 24)
# Appending predicted data for  2013    WINTER
# Size of this year and season: (8, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for  2013    SPRING
# Size of this year and season: (15, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for  2013    SUMMER
# Size of this year and season: (12, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for  2013    FALL
# Size of this year and season: (3, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for  2014    WINTER
# Size of this year and season: (0, 21)
# Interpolating TN
# Less than 2 locations have TN in this set, dropping rows without TN
# Current set is now  (0, 22)
# Interpolating TP
# Less than 2 locations have TP in this set, dropping rows without TP
# Current set is now  (0, 23)
# Interpolating VEL
# Less than 2 locations have VEL in this set, dropping rows without VEL
# Current set is now  (0, 24)
# Appending predicted data for  2014    SPRING
# Size of this year and season: (23, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for  2014    SUMMER
# Size of this year and season: (23, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for  2014    FALL
# Size of this year and season: (24, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for  2015    WINTER
# Size of this year and season: (9, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for  2015    SPRING
# Size of this year and season: (19, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for  2015    SUMMER
# Size of this year and season: (22, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for  2015    FALL
# Size of this year and season: (8, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for  2016    WINTER
# Size of this year and season: (25, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for  2016    SPRING
# Size of this year and season: (22, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for  2016    SUMMER
# Size of this year and season: (22, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for  2016    FALL
# Size of this year and season: (26, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for  2017    WINTER
# Size of this year and season: (25, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for  2017    SPRING
# Size of this year and season: (24, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for  2017    SUMMER
# Size of this year and season: (25, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for  2017    FALL
# Size of this year and season: (25, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for  2018    WINTER
# Size of this year and season: (16, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for  2018    SPRING
# Size of this year and season: (27, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for  2018    SUMMER
# Size of this year and season: (24, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for  2018    FALL
# Size of this year and season: (20, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for  2019    WINTER
# Size of this year and season: (23, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for  2019    SPRING
# Size of this year and season: (23, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for  2019    SUMMER
# Size of this year and season: (24, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for  2019    FALL
# Size of this year and season: (17, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for  2020    WINTER
# Size of this year and season: (13, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for  2020    SPRING
# Size of this year and season: (15, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for  2020    SUMMER
# Size of this year and season: (19, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Appending predicted data for  2020    FALL
# Size of this year and season: (13, 21)
# Interpolating TN
# Interpolating TP
# Interpolating VEL
# Final data set size is  (1551, 24)
# Interpolating took 0.5857407053311666 minutes

# %%
water_test_interpolated["TP error"] = abs(water_test_interpolated["PredictedTP"] - water_test_interpolated["TP"])
water_test_interpolated["TN error"] = abs(water_test_interpolated["PredictedTN"] - water_test_interpolated["TN"])
water_test_interpolated["VEL error"] = abs(water_test_interpolated["PredictedVEL"] - water_test_interpolated["VEL"])

avg_TN_error = np.mean(water_test_interpolated["TN error"])
avg_TP_error = np.mean(water_test_interpolated["TP error"])
avg_VEL_error = np.mean(water_test_interpolated["VEL error"])

print(f"Average TN error {avg_TN_error:.5f}")
print(f"Average TP error {avg_TP_error:.5f}")
print(f"Average VEL error {avg_VEL_error:.5f}")
water_test_interpolated[["TP error","TN error","VEL error"]].describe()
# Out:
# Average TN error 0.14814
# Average TP error 0.03132
# Average VEL error 0.25293
#           TP error     TN error    VEL error
# count  1551.000000  1551.000000  1551.000000
# mean      0.031320     0.148139     0.252930
# std       0.048017     0.193998     0.257600
# min       0.000000     0.000000     0.000000
# 25%       0.006590     0.041333     0.066501
# 50%       0.016524     0.089949     0.167256
# 75%       0.034509     0.166094     0.351991
# max       0.751988     1.824086     1.528761

# %% [markdown]
# ### Multivariate Regression Attempt on Open River

# %% [markdown]
# Filter for non missing data

# %%
cols = ['TP','TN','CHLcal','SS','VEL','DO','COND','WDP','TURB','TEMP','SECCHI']
print("Filtering out all rows with missing data")
qualdata = water_data.dropna(axis=0, how='any', thresh=None, subset=cols, inplace=False).copy()
print(qualdata.shape)
print("Filtering out colums that we dont need")
qualdata.drop(qualdata.columns.difference(cols), 1, inplace=True)
print(qualdata.shape)
# Out:
# Filtering out all rows with missing data
# (1943, 21)
# Filtering out colums that we dont need
# (1943, 11)

# %%
# Model Hyperparameter: Set the degree of the polynomial to fit
d = 5


X = np.array(qualdata[['CHLcal','SS','VEL','DO','COND','WDP','TURB','TEMP','SECCHI']])
TP = np.array(qualdata['TP'])
TN = np.array(qualdata['TN'])

# Good idea to standardize predictor attributes - assumes each variable has a decently normal distribution
scaler = RobustScaler().fit(X)
X_standard = scaler.transform(X)


# The PolynomialFeatures class in sklearn.preprocessing can be used to transform a data matrix by
# adding higher-order and interaction terms for the existing features. It also adds a "zeroth"
# column consisting of all 1's that corresponds to the weight w_0 in a regression model.
poly = PolynomialFeatures(d)

# We "fit" the poly object to our data matrix to allow it to identify the structure of the data
# (notably the number of attributes, or columns, in the data matrix).
poly.fit(X_standard)
#poly.fit(X)


# Now we use poly.transform to add any higher-order terms to the data matrix.
# This also adds a zeroth attribute which is set to all 1's.
augmented_X = poly.transform(X_standard)
#augmented_X = poly.transform(X)


# Next we create a linear regression object (named lm for "linear model").
# Because our augmented data matrix includes an all 1's column, we don't
# need to fit the intercept (w_0) here.
TP_lm = LinearRegression(fit_intercept=False)
TN_lm = LinearRegression(fit_intercept=False)


# Split data into train and test for each
TPX_train, TPX_test, TPy_train, TPy_test = train_test_split(augmented_X, TP, train_size=0.7)
TNX_train, TNX_test, TNy_train, TNy_test = train_test_split(augmented_X, TN, train_size=0.7)

# Fit models using training data
TP_lm.fit(TPX_train, TPy_train)
TN_lm.fit(TNX_train, TNy_train)

# After fitting the regression model, we can estimate the error
# Get training errors
TP_train_err = np.mean((TPy_train - TP_lm.predict(TPX_train)) ** 2)
TN_train_err = np.mean((TNy_train - TN_lm.predict(TNX_train)) ** 2)

# Get test errors
TP_test_err = np.mean((TPy_test - TP_lm.predict(TPX_test)) ** 2)
TN_test_err = np.mean((TNy_test - TN_lm.predict(TNX_test)) ** 2)

# Report
print("TP training set mean squared error: {:.6f}".format(TP_train_err)," on average off {:.6f}".format(np.sqrt(TP_train_err)))
print("TN training set mean squared error: {:.6f}".format(TN_train_err)," on average off {:.6f}".format(np.sqrt(TN_train_err)),"\n")
print("TP test set mean squared error: {:.6f}".format(TP_test_err)," on average off {:.6f}".format(np.sqrt(TP_test_err)))
print("TN test set mean squared error: {:.6f}".format(TN_test_err)," on average off {:.6f}".format(np.sqrt(TN_test_err)),"\n")
# Out:
# TP training set mean squared error: 0.000000  on average off 0.000000
# TN training set mean squared error: 0.000000  on average off 0.000000
#
# TP test set mean squared error: 153.344687  on average off 12.383242
# TN test set mean squared error: 41933.312604  on average off 204.776250
